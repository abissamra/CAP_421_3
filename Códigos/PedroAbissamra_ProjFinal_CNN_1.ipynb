# %% [markdown]
# # Pedro de Figueiredo Abissamra

# %% [markdown]
# ## Rede CNN baseada no artigo "Over-the-Air Deep Learning Based Radio Signal Classification"

# %%
#Bibliotecas de processamento d sinal
import scipy.io as io
from scipy import signal
import numpy as np
import h5py
import math
import matplotlib.pyplot as plt
import random
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import time

#Biblioteca de aprendizado de máquina
import tensorflow as tf
from keras.layers import Dense
from keras.layers import Dropout
from tensorflow.keras.utils import Sequence
from keras.layers import Conv1D, MaxPooling1D
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from tensorflow.keras.callbacks import ModelCheckpoint
from keras.callbacks import Callback

# %%
# Verifica se existe GPU disponível
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

# Verifica detalhes da GPU, se disponível
if len(tf.config.experimental.list_physical_devices('GPU')) > 0:
    print("Using GPU:", tf.config.experimental.list_physical_devices('GPU')[0])
else:
    print("No GPU detected, using CPU")
# Out:
# Num GPUs Available:  1
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
# Limita o crescimento da memória da GPU
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    tf.config.experimental.set_memory_growth(device, True)

# %%
# Caminho do dataset
dataset_path = "C:/Users/Andrey/Desktop/PEDRO/"

# %%
# Impotação dos dados de entrada
with h5py.File(dataset_path +'X_train.mat', 'r') as f:
    X_train = np.array(f['X_train'], dtype='float32').T
with h5py.File(dataset_path +'X_val.mat', 'r') as f:
   X_val = np.array(f['X_val'], dtype='float32').T
with h5py.File(dataset_path +'X_test.mat', 'r') as f:
    X_test = np.array(f['X_test'], dtype='float32').T

# %%
# Importação dos dados de saída e labels
Y_train = io.loadmat(dataset_path + 'Y_train.mat')['Y_train']
Y_val = io.loadmat(dataset_path + 'Y_val.mat')['Y_val']
Y_test = io.loadmat(dataset_path + 'Y_test.mat')['Y_test']
lbl_train = io.loadmat(dataset_path + 'lbl_train.mat')['lbl_train']
lbl_val = io.loadmat(dataset_path + 'lbl_val.mat')['lbl_val']
lbl_test = io.loadmat(dataset_path + 'lbl_test.mat')['lbl_test']

# %%
# Verificação do formato dos dados de entrada
print(X_train.shape)
print(X_test.shape)
print(X_val.shape)

# Verificação do formato dos dados de saída
print(Y_train.shape)
print(Y_test.shape)
print(Y_val.shape)

# Verificação do formato das labels
print(lbl_train.shape)
print(lbl_test.shape)
print(lbl_val.shape)
# Out:
# (469200, 1024, 2)
# (156400, 1024, 2)
# (156400, 1024, 2)
# (469200, 23)
# (156400, 23)
# (156400, 23)
# (469200, 6)
# (156400, 6)
# (156400, 6)

# %%
# Contagem da quantidade de amostras para cada um dos tipos de modulação para o dataset completo
count = np.zeros(24)
for i in range (len(Y_train)-1):
    count[int(lbl_train[i,0])] += 1
print(count)

count = np.zeros(24)
for i in range (len(Y_test)-1):
    count[int(lbl_test[i,0])] += 1
print(count)

count = np.zeros(24)
for i in range (len(Y_val)-1):
    count[int(lbl_val[i,0])] += 1
print(count)
# Out:
# [    0. 20400. 20400. 20400. 20400. 20400. 20400. 20400. 20400. 20400.
#  20400. 20400. 20400. 20400. 20400. 20400. 20400. 20400. 20400. 20400.
#  20400. 20400. 20400. 20399.]
# [   0. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800.
#  6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6799.]
# [   0. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800.
#  6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6799.]

# %%
# Seleção das modulações desejadas do dataset
desired_vals = [0, 4, 5, 8, 10, 11, 12, 13, 14, 21, 22]

# Vetores para particionamento das amostras de treino
slices_X_train = []
slices_Y_train = []
slices_lbl_train = []

# Criação dos novos dados de treinamento
for i in range(len(desired_vals)):
    slice_start = desired_vals[i] * 20400
    slice_end = (desired_vals[i] * 20400)+20400
    slices_X_train.append(X_train[slice_start:slice_end])
    slices_Y_train.append(Y_train[slice_start:slice_end])
    slices_lbl_train.append(lbl_train[slice_start:slice_end])

new_X_train = np.concatenate(slices_X_train, axis=0)
new_Y_train = np.concatenate(slices_Y_train, axis=0)
new_Y_train = new_Y_train[:, desired_vals]
new_lbl_train = np.concatenate(slices_lbl_train, axis=0)

# Verificação do formato dos novos dados de treinamento
print("New X_train shape:", new_X_train.shape)
print("New Y_train shape:", new_Y_train.shape)
print("New lbl_train shape:", new_lbl_train.shape)

# Vetores para particionamento das amostras de teste
slices_X_test = []
slices_Y_test = []
slices_lbl_test = []

# Criação dos novos dados de teste
for i in range(len(desired_vals)):
    slice_start = desired_vals[i] * 6800
    slice_end = (desired_vals[i] * 6800)+6800
    slices_X_test.append(X_test[slice_start:slice_end])
    slices_Y_test.append(Y_test[slice_start:slice_end])
    slices_lbl_test.append(lbl_test[slice_start:slice_end])

new_X_test = np.concatenate(slices_X_test, axis=0)
new_Y_test = np.concatenate(slices_Y_test, axis=0)
new_Y_test = new_Y_test[:, desired_vals]
new_lbl_test = np.concatenate(slices_lbl_test, axis=0)

# Verificação do formato dos novos dados de teste
print("New X_test shape:", new_X_test.shape)
print("New Y_test shape:", new_Y_test.shape)
print("New lbl_test shape:", new_lbl_test.shape)

# Vetores para particionamento das amostras de validação
slices_X_val = []
slices_Y_val = []
slices_lbl_val = []

# Criação dos novos dados de validação
for i in range(len(desired_vals)):
    slice_start = desired_vals[i] * 6800
    slice_end = (desired_vals[i] * 6800)+6800
    slices_X_val.append(X_val[slice_start:slice_end])
    slices_Y_val.append(Y_val[slice_start:slice_end])
    slices_lbl_val.append(lbl_val[slice_start:slice_end])

new_X_val = np.concatenate(slices_X_val, axis=0)
new_Y_val = np.concatenate(slices_Y_val, axis=0)
new_Y_val = new_Y_val[:, desired_vals]
new_lbl_val = np.concatenate(slices_lbl_val, axis=0)

# Verificação do formato dos novos dados de validação
print("New X_val shape:", new_X_val.shape)
print("New Y_val shape:", new_Y_val.shape)
print("New lbl_val shape:", new_lbl_val.shape)
# Out:
# New X_train shape: (224400, 1024, 2)
# New Y_train shape: (224400, 11)
# New lbl_train shape: (224400, 6)
# New X_test shape: (74800, 1024, 2)
# New Y_test shape: (74800, 11)
# New lbl_test shape: (74800, 6)
# New X_val shape: (74800, 1024, 2)
# New Y_val shape: (74800, 11)
# New lbl_val shape: (74800, 6)

# %%
# Contagem da quantidade de amostras para cada um dos tipos de modulação para o dataset reduzido
count = np.zeros(24)
for i in range (len(new_Y_train)-1):
    count[int(new_lbl_train[i,0])] += 1
print(count)

count = np.zeros(24)
for i in range (len(new_Y_test)-1):
    count[int(new_lbl_test[i,0])] += 1
print(count)

count = np.zeros(24)
for i in range (len(new_Y_val)-1):
    count[int(new_lbl_val[i,0])] += 1
print(count)
# Out:
# [    0. 20400.     0.     0.     0. 20400. 20400.     0.     0. 20400.
#      0. 20400. 20400. 20400. 20400. 20400.     0.     0.     0.     0.
#      0.     0. 20400. 20399.]
# [   0. 6800.    0.    0.    0. 6800. 6800.    0.    0. 6800.    0. 6800.
#  6800. 6800. 6800. 6800.    0.    0.    0.    0.    0.    0. 6800. 6799.]
# [   0. 6800.    0.    0.    0. 6800. 6800.    0.    0. 6800.    0. 6800.
#  6800. 6800. 6800. 6800.    0.    0.    0.    0.    0.    0. 6800. 6799.]

# %%
model = tf.keras.Sequential()


model.add(Conv1D(64, kernel_size=3, padding='same', activation='relu', input_shape=(1024, 2)))
model.add(MaxPooling1D(pool_size=2, padding='same'))

model.add(Conv1D(64, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2, padding='same'))

model.add(Conv1D(64, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2, padding='same'))

model.add(Conv1D(64, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2, padding='same'))

model.add(Conv1D(64, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2, padding='same'))

model.add(Conv1D(64, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2, padding='same'))

model.add(Conv1D(64, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2, padding='same'))

model.add(Flatten())
model.add(Dense(128, activation='selu')) 
model.add(Dense(128, activation='selu'))
model.add(Dense(len(desired_vals), activation='softmax'))

model.summary()

# Compilação do modelo gerado
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 1024, 64)          448
#
#  max_pooling1d (MaxPooling1D  (None, 512, 64)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 512, 64)           12352
#
#  max_pooling1d_1 (MaxPooling  (None, 256, 64)          0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 256, 64)           12352
#
#  max_pooling1d_2 (MaxPooling  (None, 128, 64)          0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 128, 64)           12352
#
#  max_pooling1d_3 (MaxPooling  (None, 64, 64)           0
#  1D)
#
#  conv1d_4 (Conv1D)           (None, 64, 64)            12352
#
#  max_pooling1d_4 (MaxPooling  (None, 32, 64)           0
#  1D)
#
#  conv1d_5 (Conv1D)           (None, 32, 64)            12352
#
#  max_pooling1d_5 (MaxPooling  (None, 16, 64)           0
#  1D)
#
#  conv1d_6 (Conv1D)           (None, 16, 64)            12352
#
#  max_pooling1d_6 (MaxPooling  (None, 8, 64)            0
#  1D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 128)               65664
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 11)                1419
#
# =================================================================
# Total params: 158,155
# Trainable params: 158,155
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Criação da classe de learning rate cíclico
class CyclicLR(Callback):
    def __init__(self, base_lr, max_lr, step_size, mode='triangular'):
        super(CyclicLR, self).__init__()
        self.base_lr = base_lr
        self.max_lr = max_lr
        self.step_size = step_size
        self.mode = mode
        self.iteration = 0
        self.history = {}

    def on_batch_end(self, batch, logs=None):
        self.iteration += 1
        cycle = np.floor(1 + self.iteration / (2 * self.step_size))
        x = np.abs(self.iteration / self.step_size - 2 * cycle + 1)
        if self.mode == 'triangular':
            lr = self.base_lr + (self.max_lr - self.base_lr) * max(0, (1 - x))
        else:
            raise ValueError("Unknown mode")
        
        self.model.optimizer.lr = lr
        self.history[self.iteration] = lr

# %%
# Configuração do checkpoint para salvar melhor modelo obtido
checkpoint = ModelCheckpoint(
    filepath="best_model_cnn.h5",       
    monitor="val_accuracy",             
    save_best_only=True,          
    mode="max",                    
    verbose=1                      
)

# %%
class DataGenerator(Sequence):
    def __init__(self, x_train, y_train, batch_size):
        self.x, self.y = x_train, y_train
        self.batch_size = batch_size

    def __len__(self):
        return int(np.ceil(len(self.x) / float(self.batch_size)))

    def __getitem__(self, idx):
        batch_x = self.x[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.y[idx * self.batch_size:(idx + 1) * self.batch_size]
        return batch_x, batch_y

train_gen = DataGenerator(new_X_train, new_Y_train, 128)
test_gen = DataGenerator(new_X_val, new_Y_val, 128)

# Definição dos valores do lr cíclico
clr = CyclicLR(base_lr=1e-7, max_lr=1e-3, step_size=50)

# Treinamento do modelo
history = model.fit(
    train_gen,
    epochs=60,
    validation_data=(new_X_val, new_Y_val),
    callbacks=[clr, checkpoint],           # Updated with the checkpoint callback
    shuffle=True
)


# Plot da acurácia do treinamento e validação
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Acurácia do modelo')
plt.ylabel('Acurácia')
plt.xlabel('Épocas')
plt.legend(['treinamento', 'validação'], loc='upper left')
plt.show()
# Out:
# Epoch 1/60
#    6/1754 [..............................] - ETA: 44s - loss: 2.4601 - accuracy: 0.0000e+00   WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0130s vs `on_train_batch_end` time: 0.0210s). Check your callbacks.
# 1754/1754 [==============================] - ETA: 0s - loss: 2.0321 - accuracy: 0.1706
# Epoch 1: val_accuracy improved from -inf to 0.24000, saving model to best_model_cnn_3.h5
# 1754/1754 [==============================] - 58s 25ms/step - loss: 2.0321 - accuracy: 0.1706 - val_loss: 1.8586 - val_accuracy: 0.2400
# Epoch 2/60
# 1754/1754 [==============================] - ETA: 0s - loss: 1.8363 - accuracy: 0.2075
# Epoch 2: val_accuracy improved from 0.24000 to 0.25512, saving model to best_model_cnn_3.h5
# 1754/1754 [==============================] - 37s 21ms/step - loss: 1.8363 - accuracy: 0.2075 - val_loss: 1.7405 - val_accuracy: 0.2551
# Epoch 3/60
# 1754/1754 [==============================] - ETA: 0s - loss: 1.8096 - accuracy: 0.2239
# Epoch 3: val_accuracy did not improve from 0.25512
# 1754/1754 [==============================] - 38s 22ms/step - loss: 1.8096 - accuracy: 0.2239 - val_loss: 1.7471 - val_accuracy: 0.2416
# Epoch 4/60
# 1753/1754 [============================>.] - ETA: 0s - loss: 1.7538 - accuracy: 0.2404
# Epoch 4: val_accuracy improved from 0.25512 to 0.27963, saving model to best_model_cnn_3.h5
# 1754/1754 [==============================] - 39s 22ms/step - loss: 1.7536 - accuracy: 0.2404 - val_loss: 1.6744 - val_accuracy: 0.2796
# Epoch 5/60
# 1752/1754 [============================>.] - ETA: 0s - loss: 1.6998 - accuracy: 0.2768
# Epoch 5: val_accuracy did not improve from 0.27963
# 1754/1754 [==============================] - 39s 22ms/step - loss: 1.6997 - accuracy: 0.2766 - val_loss: 1.7362 - val_accuracy: 0.2367
# Epoch 6/60
# 1752/1754 [============================>.] - ETA: 0s - loss: 1.6465 - accuracy: 0.2890
# Epoch 6: val_accuracy improved from 0.27963 to 0.32846, saving model to best_model_cnn_3.h5
# 1754/1754 [==============================] - 39s 22ms/step - loss: 1.6472 - accuracy: 0.2887 - val_loss: 1.5883 - val_accuracy: 0.3285
# Epoch 7/60
# 1753/1754 [============================>.] - ETA: 0s - loss: 1.4666 - accuracy: 0.3566
# Epoch 7: val_accuracy improved from 0.32846 to 0.39968, saving model to best_model_cnn_3.h5
# 1754/1754 [==============================] - 39s 23ms/step - loss: 1.4671 - accuracy: 0.3564 - val_loss: 1.3762 - val_accuracy: 0.3997
# Epoch 8/60
# 1753/1754 [============================>.] - ETA: 0s - loss: 1.2968 - accuracy: 0.4222
# Epoch 8: val_accuracy improved from 0.39968 to 0.43469, saving model to best_model_cnn_3.h5
# 1754/1754 [==============================] - 40s 23ms/step - loss: 1.2967 - accuracy: 0.4221 - val_loss: 1.2301 - val_accuracy: 0.4347
# Epoch 9/60
# 1752/1754 [============================>.] - ETA: 0s - loss: 1.1959 - accuracy: 0.4683
# Epoch 9: val_accuracy improved from 0.43469 to 0.45726, saving model to best_model_cnn_3.h5
# 1754/1754 [==============================] - 39s 22ms/step - loss: 1.1960 - accuracy: 0.4681 - val_loss: 1.2329 - val_accuracy: 0.4573
# Epoch 10/60
# 1752/1754 [============================>.] - ETA: 0s - loss: 1.1020 - accuracy: 0.5256
# Epoch 10: val_accuracy improved from 0.45726 to 0.54873, saving model to best_model_cnn_3.h5
# 1754/1754 [==============================] - 39s 22ms/step - loss: 1.1020 - accuracy: 0.5255 - val_loss: 1.0336 - val_accuracy: 0.5487
# Epoch 11/60
# 1752/1754 [============================>.] - ETA: 0s - loss: 1.0140 - accuracy: 0.5663
# Epoch 11: val_accuracy improved from 0.54873 to 0.59940, saving model to best_model_cnn_3.h5
# 1754/1754 [==============================] - 40s 23ms/step - loss: 1.0132 - accuracy: 0.5667 - val_loss: 0.9546 - val_accuracy: 0.5994
# Epoch 12/60
# 1752/1754 [============================>.] - ETA: 0s - loss: 0.9540 - accuracy: 0.5861
# Epoch 12: val_accuracy improved from 0.59940 to 0.60436, saving model to best_model_cnn_3.h5
# 1754/1754 [==============================] - 39s 22ms/step - loss: 0.9540 - accuracy: 0.5859 - val_loss: 0.9371 - val_accuracy: 0.6044
# Epoch 13/60
# 1753/1754 [============================>.] - ETA: 0s - loss: 0.9113 - accuracy: 0.6152
# Epoch 13: val_accuracy improved from 0.60436 to 0.62612, saving model to best_model_cnn_3.h5
# 1754/1754 [==============================] - 39s 22ms/step - loss: 0.9108 - accuracy: 0.6155 - val_loss: 0.8710 - val_accuracy: 0.6261
# Epoch 14/60
# 1753/1754 [============================>.] - ETA: 0s - loss: 0.8860 - accuracy: 0.6247
# Epoch 14: val_accuracy did not improve from 0.62612
# 1754/1754 [==============================] - 39s 22ms/step - loss: 0.8856 - accuracy: 0.6249 - val_loss: 0.9388 - val_accuracy: 0.6223
# Epoch 15/60
# 1754/1754 [==============================] - ETA: 0s - loss: 0.8640 - accuracy: 0.6365
# Epoch 15: val_accuracy improved from 0.62612 to 0.64587, saving model to best_model_cnn_3.h5
# 1754/1754 [==============================] - 39s 23ms/step - loss: 0.8640 - accuracy: 0.6365 - val_loss: 0.8342 - val_accuracy: 0.6459
# Epoch 16/60
# 1752/1754 [============================>.] - ETA: 0s - loss: 0.8174 - accuracy: 0.6617
# Epoch 16: val_accuracy improved from 0.64587 to 0.66032, saving model to best_model_cnn_3.h5
# 1754/1754 [==============================] - 40s 23ms/step - loss: 0.8179 - accuracy: 0.6615 - val_loss: 0.8535 - val_accuracy: 0.6603
# Epoch 17/60
# 1753/1754 [============================>.] - ETA: 0s - loss: 0.8191 - accuracy: 0.6641
# Epoch 17: val_accuracy improved from 0.66032 to 0.69902, saving model to best_model_cnn_3.h5
# 1754/1754 [==============================] - 39s 23ms/step - loss: 0.8195 - accuracy: 0.6637 - val_loss: 0.7426 - val_accuracy: 0.6990
# Epoch 18/60
# 1751/1754 [============================>.] - ETA: 0s - loss: 0.7692 - accuracy: 0.6840
# Epoch 18: val_accuracy did not improve from 0.69902
# 1754/1754 [==============================] - 39s 22ms/step - loss: 0.7697 - accuracy: 0.6840 - val_loss: 1.0859 - val_accuracy: 0.5838
# Epoch 19/60
# 1752/1754 [============================>.] - ETA: 0s - loss: 0.7492 - accuracy: 0.6961
# Epoch 19: val_accuracy improved from 0.69902 to 0.71118, saving model to best_model_cnn_3.h5
# 1754/1754 [==============================] - 40s 23ms/step - loss: 0.7485 - accuracy: 0.6964 - val_loss: 0.7124 - val_accuracy: 0.7112
# Epoch 20/60
# 1754/1754 [==============================] - ETA: 0s - loss: 0.7196 - accuracy: 0.7080
# Epoch 20: val_accuracy did not improve from 0.71118
# 1754/1754 [==============================] - 39s 22ms/step - loss: 0.7196 - accuracy: 0.7080 - val_loss: 0.7090 - val_accuracy: 0.7100
# Epoch 21/60
# 1754/1754 [==============================] - ETA: 0s - loss: 0.7259 - accuracy: 0.7094
# Epoch 21: val_accuracy did not improve from 0.71118
# 1754/1754 [==============================] - 39s 22ms/step - loss: 0.7259 - accuracy: 0.7094 - val_loss: 0.7105 - val_accuracy: 0.7038
# Epoch 22/60
# 1754/1754 [==============================] - ETA: 0s - loss: 0.7042 - accuracy: 0.7175
# Epoch 22: val_accuracy improved from 0.71118 to 0.72793, saving model to best_model_cnn_3.h5
# 1754/1754 [==============================] - 40s 23ms/step - loss: 0.7042 - accuracy: 0.7175 - val_loss: 0.6989 - val_accuracy: 0.7279
# Epoch 23/60
# 1752/1754 [============================>.] - ETA: 0s - loss: 0.6709 - accuracy: 0.7293
# Epoch 23: val_accuracy did not improve from 0.72793
# 1754/1754 [==============================] - 41s 24ms/step - loss: 0.6712 - accuracy: 0.7291 - val_loss: 0.6677 - val_accuracy: 0.7247
# Epoch 24/60
# 1754/1754 [==============================] - ETA: 0s - loss: 0.6872 - accuracy: 0.7247
# Epoch 24: val_accuracy improved from 0.72793 to 0.73461, saving model to best_model_cnn_3.h5
# 1754/1754 [==============================] - 40s 23ms/step - loss: 0.6872 - accuracy: 0.7247 - val_loss: 0.6665 - val_accuracy: 0.7346
# Epoch 25/60
# 1753/1754 [============================>.] - ETA: 0s - loss: 0.6431 - accuracy: 0.7388
# Epoch 25: val_accuracy did not improve from 0.73461
# 1754/1754 [==============================] - 41s 23ms/step - loss: 0.6439 - accuracy: 0.7385 - val_loss: 0.7389 - val_accuracy: 0.6899
# Epoch 26/60
# 1754/1754 [==============================] - ETA: 0s - loss: 0.6400 - accuracy: 0.7431
# Epoch 26: val_accuracy did not improve from 0.73461
# 1754/1754 [==============================] - 39s 22ms/step - loss: 0.6400 - accuracy: 0.7431 - val_loss: 0.7569 - val_accuracy: 0.6980
# Epoch 27/60
# 1752/1754 [============================>.] - ETA: 0s - loss: 0.6253 - accuracy: 0.7457
# Epoch 27: val_accuracy did not improve from 0.73461
# 1754/1754 [==============================] - 40s 23ms/step - loss: 0.6254 - accuracy: 0.7456 - val_loss: 0.7764 - val_accuracy: 0.7090
# Epoch 28/60
# 1753/1754 [============================>.] - ETA: 0s - loss: 0.6165 - accuracy: 0.7475
# Epoch 28: val_accuracy did not improve from 0.73461
# 1754/1754 [==============================] - 39s 23ms/step - loss: 0.6165 - accuracy: 0.7475 - val_loss: 0.6633 - val_accuracy: 0.7336
# Epoch 29/60
# 1753/1754 [============================>.] - ETA: 0s - loss: 0.6042 - accuracy: 0.7568
# Epoch 29: val_accuracy improved from 0.73461 to 0.75215, saving model to best_model_cnn_3.h5
# 1754/1754 [==============================] - 39s 22ms/step - loss: 0.6041 - accuracy: 0.7569 - val_loss: 0.6352 - val_accuracy: 0.7522
# Epoch 30/60
# 1754/1754 [==============================] - ETA: 0s - loss: 0.5980 - accuracy: 0.7577
# Epoch 30: val_accuracy did not improve from 0.75215
# 1754/1754 [==============================] - 40s 23ms/step - loss: 0.5980 - accuracy: 0.7577 - val_loss: 0.6212 - val_accuracy: 0.7456
# Epoch 31/60
# 1754/1754 [==============================] - ETA: 0s - loss: 0.5961 - accuracy: 0.7591
# Epoch 31: val_accuracy did not improve from 0.75215
# 1754/1754 [==============================] - 40s 23ms/step - loss: 0.5961 - accuracy: 0.7591 - val_loss: 0.6700 - val_accuracy: 0.7393
# Epoch 32/60
# 1754/1754 [==============================] - ETA: 0s - loss: 0.5811 - accuracy: 0.7609
# Epoch 32: val_accuracy did not improve from 0.75215
# 1754/1754 [==============================] - 40s 23ms/step - loss: 0.5811 - accuracy: 0.7609 - val_loss: 0.6644 - val_accuracy: 0.7449
# Epoch 33/60
# 1752/1754 [============================>.] - ETA: 0s - loss: 0.5853 - accuracy: 0.7637
# Epoch 33: val_accuracy did not improve from 0.75215
# 1754/1754 [==============================] - 40s 23ms/step - loss: 0.5848 - accuracy: 0.7639 - val_loss: 0.7079 - val_accuracy: 0.7217
# Epoch 34/60
# 1753/1754 [============================>.] - ETA: 0s - loss: 0.6077 - accuracy: 0.7567
# Epoch 34: val_accuracy did not improve from 0.75215
# 1754/1754 [==============================] - 39s 22ms/step - loss: 0.6081 - accuracy: 0.7565 - val_loss: 0.6234 - val_accuracy: 0.7462
# Epoch 35/60
# 1753/1754 [============================>.] - ETA: 0s - loss: 0.5765 - accuracy: 0.7665
# Epoch 35: val_accuracy did not improve from 0.75215
# 1754/1754 [==============================] - 39s 22ms/step - loss: 0.5761 - accuracy: 0.7666 - val_loss: 0.6993 - val_accuracy: 0.7347
# Epoch 36/60
# 1752/1754 [============================>.] - ETA: 0s - loss: 0.5545 - accuracy: 0.7725
# Epoch 36: val_accuracy did not improve from 0.75215
# 1754/1754 [==============================] - 39s 22ms/step - loss: 0.5539 - accuracy: 0.7727 - val_loss: 0.6215 - val_accuracy: 0.7480
# Epoch 37/60
# 1753/1754 [============================>.] - ETA: 0s - loss: 0.5650 - accuracy: 0.7709
# Epoch 37: val_accuracy did not improve from 0.75215
# 1754/1754 [==============================] - 40s 23ms/step - loss: 0.5655 - accuracy: 0.7708 - val_loss: 0.6257 - val_accuracy: 0.7505
# Epoch 38/60
# 1753/1754 [============================>.] - ETA: 0s - loss: 0.5585 - accuracy: 0.7740
# Epoch 38: val_accuracy did not improve from 0.75215
# 1754/1754 [==============================] - 40s 23ms/step - loss: 0.5583 - accuracy: 0.7742 - val_loss: 0.6462 - val_accuracy: 0.7503
# Epoch 39/60
# 1754/1754 [==============================] - ETA: 0s - loss: 0.5571 - accuracy: 0.7744
# Epoch 39: val_accuracy did not improve from 0.75215
# 1754/1754 [==============================] - 40s 23ms/step - loss: 0.5571 - accuracy: 0.7744 - val_loss: 0.6806 - val_accuracy: 0.7305
# Epoch 40/60
# 1753/1754 [============================>.] - ETA: 0s - loss: 0.5454 - accuracy: 0.7791
# Epoch 40: val_accuracy did not improve from 0.75215
# 1754/1754 [==============================] - 39s 22ms/step - loss: 0.5451 - accuracy: 0.7792 - val_loss: 0.7816 - val_accuracy: 0.7256
# Epoch 41/60
# 1753/1754 [============================>.] - ETA: 0s - loss: 0.5347 - accuracy: 0.7849
# Epoch 41: val_accuracy did not improve from 0.75215
# 1754/1754 [==============================] - 40s 23ms/step - loss: 0.5344 - accuracy: 0.7850 - val_loss: 0.6800 - val_accuracy: 0.7330
# Epoch 42/60
# 1752/1754 [============================>.] - ETA: 0s - loss: 0.5699 - accuracy: 0.7733
# Epoch 42: val_accuracy improved from 0.75215 to 0.75702, saving model to best_model_cnn_3.h5
# 1754/1754 [==============================] - 44s 25ms/step - loss: 0.5693 - accuracy: 0.7735 - val_loss: 0.6053 - val_accuracy: 0.7570
# Epoch 43/60
# 1752/1754 [============================>.] - ETA: 0s - loss: 0.5281 - accuracy: 0.7859
# Epoch 43: val_accuracy did not improve from 0.75702
# 1754/1754 [==============================] - 46s 26ms/step - loss: 0.5286 - accuracy: 0.7856 - val_loss: 0.6257 - val_accuracy: 0.7530
# Epoch 44/60
# 1754/1754 [==============================] - ETA: 0s - loss: 0.5187 - accuracy: 0.7859
# Epoch 44: val_accuracy did not improve from 0.75702
# 1754/1754 [==============================] - 44s 25ms/step - loss: 0.5187 - accuracy: 0.7859 - val_loss: 0.6218 - val_accuracy: 0.7454
# Epoch 45/60
# 1753/1754 [============================>.] - ETA: 0s - loss: 0.5221 - accuracy: 0.7879
# Epoch 45: val_accuracy improved from 0.75702 to 0.75766, saving model to best_model_cnn_3.h5
# 1754/1754 [==============================] - 41s 24ms/step - loss: 0.5218 - accuracy: 0.7880 - val_loss: 0.6219 - val_accuracy: 0.7577
# Epoch 46/60
# 1752/1754 [============================>.] - ETA: 0s - loss: 0.5382 - accuracy: 0.7850
# Epoch 46: val_accuracy did not improve from 0.75766
# 1754/1754 [==============================] - 40s 23ms/step - loss: 0.5377 - accuracy: 0.7852 - val_loss: 0.6510 - val_accuracy: 0.7427
# Epoch 47/60
# 1754/1754 [==============================] - ETA: 0s - loss: 0.4997 - accuracy: 0.7951
# Epoch 47: val_accuracy improved from 0.75766 to 0.75830, saving model to best_model_cnn_3.h5
# 1754/1754 [==============================] - 40s 23ms/step - loss: 0.4997 - accuracy: 0.7951 - val_loss: 0.6080 - val_accuracy: 0.7583
# Epoch 48/60
# 1752/1754 [============================>.] - ETA: 0s - loss: 0.5152 - accuracy: 0.7947
# Epoch 48: val_accuracy did not improve from 0.75830
# 1754/1754 [==============================] - 39s 22ms/step - loss: 0.5153 - accuracy: 0.7947 - val_loss: 0.6694 - val_accuracy: 0.7471
# Epoch 49/60
# 1754/1754 [==============================] - ETA: 0s - loss: 0.5049 - accuracy: 0.7940
# Epoch 49: val_accuracy improved from 0.75830 to 0.75844, saving model to best_model_cnn_3.h5
# 1754/1754 [==============================] - 39s 22ms/step - loss: 0.5049 - accuracy: 0.7940 - val_loss: 0.6162 - val_accuracy: 0.7584
# Epoch 50/60
# 1753/1754 [============================>.] - ETA: 0s - loss: 0.4934 - accuracy: 0.7994
# Epoch 50: val_accuracy did not improve from 0.75844
# 1754/1754 [==============================] - 39s 22ms/step - loss: 0.4931 - accuracy: 0.7995 - val_loss: 0.6289 - val_accuracy: 0.7493
# Epoch 51/60
# 1752/1754 [============================>.] - ETA: 0s - loss: 0.5059 - accuracy: 0.7952
# Epoch 51: val_accuracy did not improve from 0.75844
# 1754/1754 [==============================] - 40s 23ms/step - loss: 0.5062 - accuracy: 0.7950 - val_loss: 0.7525 - val_accuracy: 0.7295
# Epoch 52/60
# 1754/1754 [==============================] - ETA: 0s - loss: 0.5182 - accuracy: 0.7939
# Epoch 52: val_accuracy improved from 0.75844 to 0.76225, saving model to best_model_cnn_3.h5
# 1754/1754 [==============================] - 39s 22ms/step - loss: 0.5182 - accuracy: 0.7939 - val_loss: 0.6228 - val_accuracy: 0.7622
# Epoch 53/60
# 1754/1754 [==============================] - ETA: 0s - loss: 0.4852 - accuracy: 0.8044
# Epoch 53: val_accuracy did not improve from 0.76225
# 1754/1754 [==============================] - 40s 23ms/step - loss: 0.4852 - accuracy: 0.8044 - val_loss: 0.6511 - val_accuracy: 0.7604
# Epoch 54/60
# 1754/1754 [==============================] - ETA: 0s - loss: 0.4944 - accuracy: 0.8002
# Epoch 54: val_accuracy did not improve from 0.76225
# 1754/1754 [==============================] - 40s 23ms/step - loss: 0.4944 - accuracy: 0.8002 - val_loss: 0.6302 - val_accuracy: 0.7546
# Epoch 55/60
# 1753/1754 [============================>.] - ETA: 0s - loss: 0.4840 - accuracy: 0.8018
# Epoch 55: val_accuracy did not improve from 0.76225
# 1754/1754 [==============================] - 39s 22ms/step - loss: 0.4837 - accuracy: 0.8019 - val_loss: 0.6497 - val_accuracy: 0.7566
# Epoch 56/60
# 1752/1754 [============================>.] - ETA: 0s - loss: 0.4785 - accuracy: 0.8077
# Epoch 56: val_accuracy did not improve from 0.76225
# 1754/1754 [==============================] - 39s 22ms/step - loss: 0.4787 - accuracy: 0.8076 - val_loss: 0.6530 - val_accuracy: 0.7520
# Epoch 57/60
# 1752/1754 [============================>.] - ETA: 0s - loss: 0.4672 - accuracy: 0.8104
# Epoch 57: val_accuracy did not improve from 0.76225
# 1754/1754 [==============================] - 40s 23ms/step - loss: 0.4684 - accuracy: 0.8099 - val_loss: 0.6362 - val_accuracy: 0.7618
# Epoch 58/60
# 1752/1754 [============================>.] - ETA: 0s - loss: 0.4910 - accuracy: 0.8043
# Epoch 58: val_accuracy did not improve from 0.76225
# 1754/1754 [==============================] - 40s 23ms/step - loss: 0.4906 - accuracy: 0.8045 - val_loss: 0.6476 - val_accuracy: 0.7594
# Epoch 59/60
# 1753/1754 [============================>.] - ETA: 0s - loss: 0.4658 - accuracy: 0.8140
# Epoch 59: val_accuracy did not improve from 0.76225
# 1754/1754 [==============================] - 40s 23ms/step - loss: 0.4656 - accuracy: 0.8141 - val_loss: 0.6219 - val_accuracy: 0.7618
# Epoch 60/60
# 1752/1754 [============================>.] - ETA: 0s - loss: 0.4537 - accuracy: 0.8153
# Epoch 60: val_accuracy did not improve from 0.76225
# 1754/1754 [==============================] - 40s 23ms/step - loss: 0.4536 - accuracy: 0.8153 - val_loss: 0.6388 - val_accuracy: 0.7599

# %%
# Carrega melhor modelo obtido
model = tf.keras.models.load_model('best_model_cnn.h5')

# %%
# Extração do SNR e a classe dos sinais
snr_values = np.arange(-12, 20, 2)
num_snr = len(snr_values)
num_modulations = len(desired_vals)

# Lista de nomes das modulações
modulation_names = [
"LFM", "FM_Costas", "2PSK", "PM_Barker", "PM_Frank", "PM_P1", "PM_P2", "PM_P3", "PM_P4", "Sem Modulação", "Ruído"
]

line_styles = ['-', '--', '-.', ':'] * 6
colors = plt.cm.get_cmap('tab20', num_modulations)

# Inicializar matriz para acurácia por modulação e lista para acurácia geral
accuracy_per_modulation = np.zeros((num_modulations, num_snr))
overall_accuracy = []

# Processar cada modulação para calcular a acurácia por faixa de SNR
for mod_idx in range(num_modulations):
    modulation_indices = np.where(new_Y_test[:, mod_idx] == 1)[0]
    x_modulation = new_X_test[modulation_indices]
    y_modulation = new_Y_test[modulation_indices]
    z_modulation = new_lbl_test[modulation_indices, 1]  # SNR está na segunda coluna de lbl_data

    for snr_idx, snr in enumerate(snr_values):
        snr_indices = np.where(z_modulation == snr)[0]
        x_snr = x_modulation[snr_indices]
        y_snr = y_modulation[snr_indices]
        
        if len(x_snr) == 0:
            accuracy_per_modulation[mod_idx, snr_idx] = np.nan
            continue
        
        # Fazer predições com o modelo
        predictions_snr = model.predict(x_snr)
        
        # Calcular a acurácia
        accuracy = np.mean(np.argmax(predictions_snr, axis=1) == np.argmax(y_snr, axis=1))
        accuracy_per_modulation[mod_idx, snr_idx] = accuracy

# Calcular a acurácia geral para cada faixa de SNR
for snr in snr_values:
    snr_indices = np.where(new_lbl_test[:, 1] == snr)[0]  # SNR está na segunda coluna de lbl_data
    x_snr = new_X_test[snr_indices]
    y_snr = new_Y_test[snr_indices]

    if len(x_snr) == 0:
        overall_accuracy.append(np.nan)
        continue

    # Fazer predições com o modelo
    predictions_snr = model.predict(x_snr)

    # Calcular a acurácia geral
    accuracy = np.mean(np.argmax(predictions_snr, axis=1) == np.argmax(y_snr, axis=1))
    overall_accuracy.append(accuracy)

# Converter para array numpy para facilitar o plot
overall_accuracy = np.array(overall_accuracy)

# Plotar a acurácia por modulação
plt.figure(figsize=(14, 8))
for mod_idx in range(num_modulations):
    plt.plot(
        snr_values,
        accuracy_per_modulation[mod_idx],
        label=modulation_names[mod_idx],
        linestyle=line_styles[mod_idx % len(line_styles)],
        color=colors(mod_idx)
    )

plt.xlabel("SNR (dB)")
plt.ylabel("Acurácia")
plt.title("Acurácia de Cada Modulação em Função do SNR")
plt.legend(loc="best")
plt.grid(True)
plt.show()

# Plotar a acurácia geral
plt.figure(figsize=(10, 6))
plt.plot(snr_values, overall_accuracy, marker='o', linestyle='-', color='b', label='Acurácia Geral')

plt.xlabel("SNR (dB)")
plt.ylabel("Acurácia Geral")
plt.title("Acurácia Geral da Rede em Função do SNR")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# C:\Users\Andrey\AppData\Local\Temp\ipykernel_13484\1725456917.py:12: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('tab20', num_modulations)
# 13/13 [==============================] - 0s 16ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 1ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 4ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 4ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 4ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 4ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 4ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 4ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 4ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 4ms/step
# 13/13 [==============================] - 0s 4ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 4ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 4ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 2ms/step
# 138/138 [==============================] - 0s 3ms/step
# 138/138 [==============================] - 0s 2ms/step
# 138/138 [==============================] - 0s 2ms/step
# 138/138 [==============================] - 0s 2ms/step
# 138/138 [==============================] - 0s 2ms/step
# 138/138 [==============================] - 0s 2ms/step
# 138/138 [==============================] - 0s 2ms/step
# 138/138 [==============================] - 0s 2ms/step
# 138/138 [==============================] - 0s 2ms/step
# 138/138 [==============================] - 0s 2ms/step
# 138/138 [==============================] - 0s 2ms/step
# 138/138 [==============================] - 0s 2ms/step
# 138/138 [==============================] - 0s 2ms/step
# 138/138 [==============================] - 0s 2ms/step
# 138/138 [==============================] - 0s 2ms/step
# 138/138 [==============================] - 0s 2ms/step

# %%
# Diretório de logs para o profiler
log_dir = "logs/profiler_inference"
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

# Medir o tempo de inferência
start_time = time.time()

# Realiza predições
predictions = model.predict(new_X_test)

# Medir o tempo de inferência
end_time = time.time()
inference_time = end_time - start_time

# Imprimir tempo de inferência
print(f"Tempo de inferência: {inference_time:.4f} segundos")
# Out:
# 2338/2338 [==============================] - 5s 2ms/step
# Tempo de inferência: 5.7170 segundos

# %%
# Predição utilizando melhor modelo obtido
y_pred = np.argmax(predictions, axis=1)

# Conversão do formato one hot para categórico
if len(new_Y_test.shape) > 1 and new_Y_test.shape[1] > 1:
    new_Y_test = np.argmax(new_Y_test, axis=1)

# Relatório de classificação
print("\nRelatório de Classificação:")
print(classification_report(new_Y_test, y_pred, target_names=modulation_names))

# Matriz de confusão
conf_matrix = confusion_matrix(new_Y_test, y_pred)

# Visualização da matriz de confusão
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', 
            xticklabels=modulation_names, 
            yticklabels=modulation_names)
plt.xlabel("Previsto")
plt.ylabel("Verdadeiro")
plt.title("Matriz de Confusão")
plt.show()
# Out:
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#           LFM       0.89      0.94      0.91      6800
#     FM_Costas       0.86      0.73      0.79      6800
#          2PSK       0.88      0.83      0.85      6800
#     PM_Barker       0.76      0.82      0.79      6800
#      PM_Frank       0.73      0.73      0.73      6800
#         PM_P1       0.64      0.57      0.60      6800
#         PM_P2       0.71      0.73      0.72      6800
#         PM_P3       0.68      0.76      0.72      6800
#         PM_P4       0.65      0.67      0.66      6800
# Sem Modulação       0.93      0.83      0.88      6800
#         Ruído       0.83      0.93      0.88      6800
#
#      accuracy                           0.78     74800
#     macro avg       0.78      0.78      0.77     74800
#  weighted avg       0.78      0.78      0.77     74800
