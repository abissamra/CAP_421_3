# %% [markdown]
# # Pedro de Figueiredo Abissamra

# %% [markdown]
# ## Rede LSTM Baseada no Artigo "LSTM Framework for Classification of Radar and Communication Signals"

# %%
#Bibliotecas de processamento de sinal
import scipy.io as io
from scipy import signal
import numpy as np
import h5py
import math
import matplotlib.pyplot as plt
import random
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import time

#Biblioteca de aprendizado de máquina
import tensorflow as tf
from tensorflow import keras
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Embedding
from keras.preprocessing import sequence
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from tensorflow.keras.callbacks import ModelCheckpoint
from keras.callbacks import Callback

# %%
# Verifica se existe GPU disponível
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

# Verifica detalhes da GPU, se disponível
if len(tf.config.experimental.list_physical_devices('GPU')) > 0:
    print("Using GPU:", tf.config.experimental.list_physical_devices('GPU')[0])
else:
    print("No GPU detected, using CPU")
# Out:
# Num GPUs Available:  1
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
# Limita o crescimento da memória da GPU
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    tf.config.experimental.set_memory_growth(device, True)

# %%
# Caminho do dataset
dataset_path = "C:\\Users\\abiss\\Desktop\\Pedro\\"

# %%
# Impotação dos dados de entrada
with h5py.File(dataset_path +'X_train.mat', 'r') as f:
    X_train = np.array(f['X_train'], dtype='float32').T
with h5py.File(dataset_path +'X_val.mat', 'r') as f:
   X_val = np.array(f['X_val'], dtype='float32').T
with h5py.File(dataset_path +'X_test.mat', 'r') as f:
    X_test = np.array(f['X_test'], dtype='float32').T

# %%
# Importação dos dados de saída e labels
Y_train = io.loadmat(dataset_path + 'Y_train.mat')['Y_train']
Y_val = io.loadmat(dataset_path + 'Y_val.mat')['Y_val']
Y_test = io.loadmat(dataset_path + 'Y_test.mat')['Y_test']
lbl_train = io.loadmat(dataset_path + 'lbl_train.mat')['lbl_train']
lbl_val = io.loadmat(dataset_path + 'lbl_val.mat')['lbl_val']
lbl_test = io.loadmat(dataset_path + 'lbl_test.mat')['lbl_test']

# %%
# Verificação do formato dos dados de entrada
print(X_train.shape)
print(X_test.shape)
print(X_val.shape)

# Verificação do formato dos dados de saída
print(Y_train.shape)
print(Y_test.shape)
print(Y_val.shape)

# Verificação do formato das labels
print(lbl_train.shape)
print(lbl_test.shape)
print(lbl_val.shape)
# Out:
# (469200, 1024, 2)
# (156400, 1024, 2)
# (156400, 1024, 2)
# (469200, 23)
# (156400, 23)
# (156400, 23)
# (469200, 6)
# (156400, 6)
# (156400, 6)

# %%
# Contagem da quantidade de amostras para cada um dos tipos de modulação para o dataset completo
count = np.zeros(24)
for i in range (len(Y_train)-1):
    count[int(lbl_train[i,0])] += 1
print(count)

count = np.zeros(24)
for i in range (len(Y_test)-1):
    count[int(lbl_test[i,0])] += 1
print(count)

count = np.zeros(24)
for i in range (len(Y_val)-1):
    count[int(lbl_val[i,0])] += 1
print(count)
# Out:
# [    0. 20400. 20400. 20400. 20400. 20400. 20400. 20400. 20400. 20400.
#  20400. 20400. 20400. 20400. 20400. 20400. 20400. 20400. 20400. 20400.
#  20400. 20400. 20400. 20399.]
# [   0. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800.
#  6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6799.]
# [   0. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800.
#  6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6800. 6799.]

# %%
# Seleção das modulações desejadas do dataset
desired_vals = [0, 4, 5, 8, 10, 11, 12, 13, 14, 21, 22]

# Vetores para particionamento das amostras de treino
slices_X_train = []
slices_Y_train = []
slices_lbl_train = []

# Criação dos novos dados de treinamento
for i in range(len(desired_vals)):
    slice_start = desired_vals[i] * 20400
    slice_end = (desired_vals[i] * 20400)+20400
    slices_X_train.append(X_train[slice_start:slice_end])
    slices_Y_train.append(Y_train[slice_start:slice_end])
    slices_lbl_train.append(lbl_train[slice_start:slice_end])

new_X_train = np.concatenate(slices_X_train, axis=0)
new_Y_train = np.concatenate(slices_Y_train, axis=0)
new_Y_train = new_Y_train[:, desired_vals]
new_lbl_train = np.concatenate(slices_lbl_train, axis=0)

# Verificação do formato dos novos dados de treinamento
print("New X_train shape:", new_X_train.shape)
print("New Y_train shape:", new_Y_train.shape)
print("New lbl_train shape:", new_lbl_train.shape)

# Vetores para particionamento das amostras de teste
slices_X_test = []
slices_Y_test = []
slices_lbl_test = []

# Criação dos novos dados de teste
for i in range(len(desired_vals)):
    slice_start = desired_vals[i] * 6800
    slice_end = (desired_vals[i] * 6800)+6800
    slices_X_test.append(X_test[slice_start:slice_end])
    slices_Y_test.append(Y_test[slice_start:slice_end])
    slices_lbl_test.append(lbl_test[slice_start:slice_end])

new_X_test = np.concatenate(slices_X_test, axis=0)
new_Y_test = np.concatenate(slices_Y_test, axis=0)
new_Y_test = new_Y_test[:, desired_vals]
new_lbl_test = np.concatenate(slices_lbl_test, axis=0)

# Verificação do formato dos novos dados de teste
print("New X_test shape:", new_X_test.shape)
print("New Y_test shape:", new_Y_test.shape)
print("New lbl_test shape:", new_lbl_test.shape)

# Vetores para particionamento das amostras de validação
slices_X_val = []
slices_Y_val = []
slices_lbl_val = []

# Criação dos novos dados de validação
for i in range(len(desired_vals)):
    slice_start = desired_vals[i] * 6800
    slice_end = (desired_vals[i] * 6800)+6800
    slices_X_val.append(X_val[slice_start:slice_end])
    slices_Y_val.append(Y_val[slice_start:slice_end])
    slices_lbl_val.append(lbl_val[slice_start:slice_end])

new_X_val = np.concatenate(slices_X_val, axis=0)
new_Y_val = np.concatenate(slices_Y_val, axis=0)
new_Y_val = new_Y_val[:, desired_vals]
new_lbl_val = np.concatenate(slices_lbl_val, axis=0)

# Verificação do formato dos novos dados de validação
print("New X_val shape:", new_X_val.shape)
print("New Y_val shape:", new_Y_val.shape)
print("New lbl_val shape:", new_lbl_val.shape)
# Out:
# New X_train shape: (224400, 1024, 2)
# New Y_train shape: (224400, 11)
# New lbl_train shape: (224400, 6)
# New X_test shape: (74800, 1024, 2)
# New Y_test shape: (74800, 11)
# New lbl_test shape: (74800, 6)
# New X_val shape: (74800, 1024, 2)
# New Y_val shape: (74800, 11)
# New lbl_val shape: (74800, 6)

# %%
# Contagem da quantidade de amostras para cada um dos tipos de modulação para o dataset reduzido
count = np.zeros(24)
for i in range (len(new_Y_train)-1):
    count[int(new_lbl_train[i,0])] += 1
print(count)

count = np.zeros(24)
for i in range (len(new_Y_test)-1):
    count[int(new_lbl_test[i,0])] += 1
print(count)

count = np.zeros(24)
for i in range (len(new_Y_val)-1):
    count[int(new_lbl_val[i,0])] += 1
print(count)
# Out:
# [    0. 20400.     0.     0.     0. 20400. 20400.     0.     0. 20400.
#      0. 20400. 20400. 20400. 20400. 20400.     0.     0.     0.     0.
#      0.     0. 20400. 20399.]
# [   0. 6800.    0.    0.    0. 6800. 6800.    0.    0. 6800.    0. 6800.
#  6800. 6800. 6800. 6800.    0.    0.    0.    0.    0.    0. 6800. 6799.]
# [   0. 6800.    0.    0.    0. 6800. 6800.    0.    0. 6800.    0. 6800.
#  6800. 6800. 6800. 6800.    0.    0.    0.    0.    0.    0. 6800. 6799.]

# %%
# Criando o modelo LSTM
model = Sequential()
model.add(LSTM(units=128,input_shape=(1024, 2),return_sequences=True))
model.add(LSTM(units=128,return_sequences=True))
model.add(LSTM(units=128))
model.add(Dense(len(desired_vals),activation = 'softmax'))
model.summary()

# Compilação do modelo gerado
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1024, 128)         67072
#
#  lstm_1 (LSTM)               (None, 1024, 128)         131584
#
#  lstm_2 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 11)                1419
#
# =================================================================
# Total params: 331,659
# Trainable params: 331,659
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Criação da classe de learning rate cíclico
class CyclicLR(Callback):
    def __init__(self, base_lr, max_lr, step_size, mode='triangular'):
        super(CyclicLR, self).__init__()
        self.base_lr = base_lr
        self.max_lr = max_lr
        self.step_size = step_size
        self.mode = mode
        self.iteration = 0
        self.history = {}

    def on_batch_end(self, batch, logs=None):
        self.iteration += 1
        cycle = np.floor(1 + self.iteration / (2 * self.step_size))
        x = np.abs(self.iteration / self.step_size - 2 * cycle + 1)
        if self.mode == 'triangular':
            lr = self.base_lr + (self.max_lr - self.base_lr) * max(0, (1 - x))
        else:
            raise ValueError("Unknown mode")
        
        self.model.optimizer.lr = lr
        self.history[self.iteration] = lr

# %%
# Configuração do checkpoint para salvar melhor modelo obtido
checkpoint = ModelCheckpoint(
    filepath="best_model.h5",       
    monitor="val_accuracy",             
    save_best_only=True,          
    mode="max",                    
    verbose=1                      
)

# %%
# Definição dos valores do lr cíclico
clr = CyclicLR(base_lr=1e-7, max_lr=1e-3, step_size=50)

# Treinamento do modelo
history = model.fit(
    new_X_train,
    new_Y_train,
    epochs=500,
    batch_size=512,
    validation_data=(new_X_val, new_Y_val),
    callbacks=[clr, checkpoint],
    shuffle=True
)

# Plot da acurácia dos dados de treinamento e validação
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Erro do modelo') #Obs: É acurácia, não erro!!!
plt.ylabel('Erro') #Obs: É acurácia, não erro!!!
plt.xlabel('Épocas')
plt.legend(['treinamento', 'validação'], loc='upper left')
plt.show()
# Out:
# Epoch 1/500
# 439/439 [==============================] - ETA: 0s - loss: 2.0943 - accuracy: 0.1989
# Epoch 1: val_accuracy improved from -inf to 0.17916, saving model to best_model.h5
# 439/439 [==============================] - 194s 366ms/step - loss: 2.0943 - accuracy: 0.1989 - val_loss: 2.0938 - val_accuracy: 0.1792
# Epoch 2/500
# 439/439 [==============================] - ETA: 0s - loss: 2.1301 - accuracy: 0.1949
# Epoch 2: val_accuracy did not improve from 0.17916
# 439/439 [==============================] - 159s 362ms/step - loss: 2.1301 - accuracy: 0.1949 - val_loss: 2.3985 - val_accuracy: 0.0987
# Epoch 3/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3983 - accuracy: 0.0931
# Epoch 3: val_accuracy did not improve from 0.17916
# 439/439 [==============================] - 159s 362ms/step - loss: 2.3983 - accuracy: 0.0931 - val_loss: 2.3980 - val_accuracy: 0.0909
# Epoch 4/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3984 - accuracy: 0.0923
# Epoch 4: val_accuracy did not improve from 0.17916
# 439/439 [==============================] - 160s 364ms/step - loss: 2.3984 - accuracy: 0.0923 - val_loss: 2.3983 - val_accuracy: 0.0909
# Epoch 5/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3982 - accuracy: 0.0928
# Epoch 5: val_accuracy did not improve from 0.17916
# 439/439 [==============================] - 159s 362ms/step - loss: 2.3982 - accuracy: 0.0928 - val_loss: 2.3985 - val_accuracy: 0.0909
# Epoch 6/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3984 - accuracy: 0.0909
# Epoch 6: val_accuracy did not improve from 0.17916
# 439/439 [==============================] - 159s 363ms/step - loss: 2.3984 - accuracy: 0.0909 - val_loss: 2.3994 - val_accuracy: 0.0909
# Epoch 7/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3982 - accuracy: 0.0912
# Epoch 7: val_accuracy did not improve from 0.17916
# 439/439 [==============================] - 159s 363ms/step - loss: 2.3982 - accuracy: 0.0912 - val_loss: 2.3989 - val_accuracy: 0.0909
# Epoch 8/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3983 - accuracy: 0.0913
# Epoch 8: val_accuracy did not improve from 0.17916
# 439/439 [==============================] - 159s 363ms/step - loss: 2.3983 - accuracy: 0.0913 - val_loss: 2.3981 - val_accuracy: 0.0909
# Epoch 9/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3983 - accuracy: 0.0910
# Epoch 9: val_accuracy did not improve from 0.17916
# 439/439 [==============================] - 160s 364ms/step - loss: 2.3983 - accuracy: 0.0910 - val_loss: 2.3985 - val_accuracy: 0.0909
# Epoch 10/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3981 - accuracy: 0.0913
# Epoch 10: val_accuracy did not improve from 0.17916
# 439/439 [==============================] - 158s 360ms/step - loss: 2.3981 - accuracy: 0.0913 - val_loss: 2.3980 - val_accuracy: 0.0909
# Epoch 11/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3982 - accuracy: 0.0914
# Epoch 11: val_accuracy did not improve from 0.17916
# 439/439 [==============================] - 160s 365ms/step - loss: 2.3982 - accuracy: 0.0914 - val_loss: 2.3981 - val_accuracy: 0.0909
# Epoch 12/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3982 - accuracy: 0.0909
# Epoch 12: val_accuracy did not improve from 0.17916
# 439/439 [==============================] - 159s 362ms/step - loss: 2.3982 - accuracy: 0.0909 - val_loss: 2.3982 - val_accuracy: 0.0909
# Epoch 13/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3980 - accuracy: 0.0923
# Epoch 13: val_accuracy did not improve from 0.17916
# 439/439 [==============================] - 159s 362ms/step - loss: 2.3980 - accuracy: 0.0923 - val_loss: 2.3974 - val_accuracy: 0.1177
# Epoch 14/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3981 - accuracy: 0.0917
# Epoch 14: val_accuracy did not improve from 0.17916
# 439/439 [==============================] - 159s 362ms/step - loss: 2.3981 - accuracy: 0.0917 - val_loss: 2.3980 - val_accuracy: 0.0909
# Epoch 15/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3981 - accuracy: 0.0912
# Epoch 15: val_accuracy did not improve from 0.17916
# 439/439 [==============================] - 159s 362ms/step - loss: 2.3981 - accuracy: 0.0912 - val_loss: 2.3979 - val_accuracy: 0.0909
# Epoch 16/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3980 - accuracy: 0.0899
# Epoch 16: val_accuracy did not improve from 0.17916
# 439/439 [==============================] - 159s 362ms/step - loss: 2.3980 - accuracy: 0.0899 - val_loss: 2.3980 - val_accuracy: 0.0909
# Epoch 17/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3980 - accuracy: 0.0906
# Epoch 17: val_accuracy did not improve from 0.17916
# 439/439 [==============================] - 158s 359ms/step - loss: 2.3980 - accuracy: 0.0906 - val_loss: 2.3981 - val_accuracy: 0.0909
# Epoch 18/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3867 - accuracy: 0.0967
# Epoch 18: val_accuracy did not improve from 0.17916
# 439/439 [==============================] - 157s 358ms/step - loss: 2.3867 - accuracy: 0.0967 - val_loss: 2.3022 - val_accuracy: 0.1140
# Epoch 19/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3450 - accuracy: 0.1215
# Epoch 19: val_accuracy did not improve from 0.17916
# 439/439 [==============================] - 158s 359ms/step - loss: 2.3450 - accuracy: 0.1215 - val_loss: 2.3675 - val_accuracy: 0.0976
# Epoch 20/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3795 - accuracy: 0.1098
# Epoch 20: val_accuracy did not improve from 0.17916
# 439/439 [==============================] - 157s 358ms/step - loss: 2.3795 - accuracy: 0.1098 - val_loss: 2.3990 - val_accuracy: 0.0911
# Epoch 21/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3741 - accuracy: 0.1176
# Epoch 21: val_accuracy did not improve from 0.17916
# 439/439 [==============================] - 157s 357ms/step - loss: 2.3741 - accuracy: 0.1176 - val_loss: 2.3705 - val_accuracy: 0.0936
# Epoch 22/500
# 439/439 [==============================] - ETA: 0s - loss: 2.2465 - accuracy: 0.1470
# Epoch 22: val_accuracy did not improve from 0.17916
# 439/439 [==============================] - 157s 359ms/step - loss: 2.2465 - accuracy: 0.1470 - val_loss: 2.1221 - val_accuracy: 0.1596
# Epoch 23/500
# 439/439 [==============================] - ETA: 0s - loss: 2.1230 - accuracy: 0.1913
# Epoch 23: val_accuracy improved from 0.17916 to 0.18886, saving model to best_model.h5
# 439/439 [==============================] - 158s 359ms/step - loss: 2.1230 - accuracy: 0.1913 - val_loss: 2.0782 - val_accuracy: 0.1889
# Epoch 24/500
# 439/439 [==============================] - ETA: 0s - loss: 2.1137 - accuracy: 0.1968
# Epoch 24: val_accuracy improved from 0.18886 to 0.22122, saving model to best_model.h5
# 439/439 [==============================] - 157s 359ms/step - loss: 2.1137 - accuracy: 0.1968 - val_loss: 2.0339 - val_accuracy: 0.2212
# Epoch 25/500
# 439/439 [==============================] - ETA: 0s - loss: 2.0092 - accuracy: 0.2308
# Epoch 25: val_accuracy improved from 0.22122 to 0.23297, saving model to best_model.h5
# 439/439 [==============================] - 158s 359ms/step - loss: 2.0092 - accuracy: 0.2308 - val_loss: 1.9278 - val_accuracy: 0.2330
# Epoch 26/500
# 439/439 [==============================] - ETA: 0s - loss: 1.8852 - accuracy: 0.2613
# Epoch 26: val_accuracy improved from 0.23297 to 0.28269, saving model to best_model.h5
# 439/439 [==============================] - 157s 359ms/step - loss: 1.8852 - accuracy: 0.2613 - val_loss: 1.7970 - val_accuracy: 0.2827
# Epoch 27/500
# 439/439 [==============================] - ETA: 0s - loss: 1.7929 - accuracy: 0.3062
# Epoch 27: val_accuracy improved from 0.28269 to 0.30459, saving model to best_model.h5
# 439/439 [==============================] - 157s 358ms/step - loss: 1.7929 - accuracy: 0.3062 - val_loss: 1.7509 - val_accuracy: 0.3046
# Epoch 28/500
# 439/439 [==============================] - ETA: 0s - loss: 1.6867 - accuracy: 0.3487
# Epoch 28: val_accuracy improved from 0.30459 to 0.35956, saving model to best_model.h5
# 439/439 [==============================] - 158s 359ms/step - loss: 1.6867 - accuracy: 0.3487 - val_loss: 1.6330 - val_accuracy: 0.3596
# Epoch 29/500
# 439/439 [==============================] - ETA: 0s - loss: 1.6063 - accuracy: 0.3821
# Epoch 29: val_accuracy improved from 0.35956 to 0.39151, saving model to best_model.h5
# 439/439 [==============================] - 158s 359ms/step - loss: 1.6063 - accuracy: 0.3821 - val_loss: 1.5556 - val_accuracy: 0.3915
# Epoch 30/500
# 439/439 [==============================] - ETA: 0s - loss: 1.5367 - accuracy: 0.4060
# Epoch 30: val_accuracy improved from 0.39151 to 0.40820, saving model to best_model.h5
# 439/439 [==============================] - 157s 359ms/step - loss: 1.5367 - accuracy: 0.4060 - val_loss: 1.4644 - val_accuracy: 0.4082
# Epoch 31/500
# 439/439 [==============================] - ETA: 0s - loss: 1.4235 - accuracy: 0.4471
# Epoch 31: val_accuracy improved from 0.40820 to 0.46570, saving model to best_model.h5
# 439/439 [==============================] - 157s 359ms/step - loss: 1.4235 - accuracy: 0.4471 - val_loss: 1.3407 - val_accuracy: 0.4657
# Epoch 32/500
# 439/439 [==============================] - ETA: 0s - loss: 1.3377 - accuracy: 0.4788
# Epoch 32: val_accuracy did not improve from 0.46570
# 439/439 [==============================] - 157s 358ms/step - loss: 1.3377 - accuracy: 0.4788 - val_loss: 1.3771 - val_accuracy: 0.4366
# Epoch 33/500
# 439/439 [==============================] - ETA: 0s - loss: 1.2549 - accuracy: 0.5094
# Epoch 33: val_accuracy improved from 0.46570 to 0.52342, saving model to best_model.h5
# 439/439 [==============================] - 157s 359ms/step - loss: 1.2549 - accuracy: 0.5094 - val_loss: 1.2005 - val_accuracy: 0.5234
# Epoch 34/500
# 439/439 [==============================] - ETA: 0s - loss: 1.1844 - accuracy: 0.5362
# Epoch 34: val_accuracy improved from 0.52342 to 0.52548, saving model to best_model.h5
# 439/439 [==============================] - 157s 358ms/step - loss: 1.1844 - accuracy: 0.5362 - val_loss: 1.1959 - val_accuracy: 0.5255
# Epoch 35/500
# 439/439 [==============================] - ETA: 0s - loss: 1.1139 - accuracy: 0.5626
# Epoch 35: val_accuracy improved from 0.52548 to 0.57025, saving model to best_model.h5
# 439/439 [==============================] - 157s 358ms/step - loss: 1.1139 - accuracy: 0.5626 - val_loss: 1.0924 - val_accuracy: 0.5703
# Epoch 36/500
# 439/439 [==============================] - ETA: 0s - loss: 1.0469 - accuracy: 0.5887
# Epoch 36: val_accuracy improved from 0.57025 to 0.60294, saving model to best_model.h5
# 439/439 [==============================] - 157s 358ms/step - loss: 1.0469 - accuracy: 0.5887 - val_loss: 0.9995 - val_accuracy: 0.6029
# Epoch 37/500
# 439/439 [==============================] - ETA: 0s - loss: 1.0131 - accuracy: 0.6015
# Epoch 37: val_accuracy did not improve from 0.60294
# 439/439 [==============================] - 157s 358ms/step - loss: 1.0131 - accuracy: 0.6015 - val_loss: 1.0085 - val_accuracy: 0.5955
# Epoch 38/500
# 439/439 [==============================] - ETA: 0s - loss: 0.9646 - accuracy: 0.6209
# Epoch 38: val_accuracy improved from 0.60294 to 0.62904, saving model to best_model.h5
# 439/439 [==============================] - 157s 359ms/step - loss: 0.9646 - accuracy: 0.6209 - val_loss: 0.9372 - val_accuracy: 0.6290
# Epoch 39/500
# 439/439 [==============================] - ETA: 0s - loss: 0.9296 - accuracy: 0.6338
# Epoch 39: val_accuracy improved from 0.62904 to 0.64189, saving model to best_model.h5
# 439/439 [==============================] - 157s 359ms/step - loss: 0.9296 - accuracy: 0.6338 - val_loss: 0.9006 - val_accuracy: 0.6419
# Epoch 40/500
# 439/439 [==============================] - ETA: 0s - loss: 0.9008 - accuracy: 0.6450
# Epoch 40: val_accuracy did not improve from 0.64189
# 439/439 [==============================] - 158s 359ms/step - loss: 0.9008 - accuracy: 0.6450 - val_loss: 0.9309 - val_accuracy: 0.6320
# Epoch 41/500
# 439/439 [==============================] - ETA: 0s - loss: 0.8688 - accuracy: 0.6565
# Epoch 41: val_accuracy improved from 0.64189 to 0.66222, saving model to best_model.h5
# 439/439 [==============================] - 157s 358ms/step - loss: 0.8688 - accuracy: 0.6565 - val_loss: 0.8416 - val_accuracy: 0.6622
# Epoch 42/500
# 439/439 [==============================] - ETA: 0s - loss: 0.8629 - accuracy: 0.6604
# Epoch 42: val_accuracy did not improve from 0.66222
# 439/439 [==============================] - 157s 358ms/step - loss: 0.8629 - accuracy: 0.6604 - val_loss: 0.8952 - val_accuracy: 0.6494
# Epoch 43/500
# 439/439 [==============================] - ETA: 0s - loss: 1.1136 - accuracy: 0.5743
# Epoch 43: val_accuracy did not improve from 0.66222
# 439/439 [==============================] - 157s 359ms/step - loss: 1.1136 - accuracy: 0.5743 - val_loss: 0.9459 - val_accuracy: 0.6228
# Epoch 44/500
# 439/439 [==============================] - ETA: 0s - loss: 0.8631 - accuracy: 0.6581
# Epoch 44: val_accuracy improved from 0.66222 to 0.67047, saving model to best_model.h5
# 439/439 [==============================] - 157s 359ms/step - loss: 0.8631 - accuracy: 0.6581 - val_loss: 0.8281 - val_accuracy: 0.6705
# Epoch 45/500
# 439/439 [==============================] - ETA: 0s - loss: 0.7995 - accuracy: 0.6830
# Epoch 45: val_accuracy did not improve from 0.67047
# 439/439 [==============================] - 158s 359ms/step - loss: 0.7995 - accuracy: 0.6830 - val_loss: 0.9248 - val_accuracy: 0.6386
# Epoch 46/500
# 439/439 [==============================] - ETA: 0s - loss: 0.7904 - accuracy: 0.6866
# Epoch 46: val_accuracy improved from 0.67047 to 0.69047, saving model to best_model.h5
# 439/439 [==============================] - 158s 359ms/step - loss: 0.7904 - accuracy: 0.6866 - val_loss: 0.7811 - val_accuracy: 0.6905
# Epoch 47/500
# 439/439 [==============================] - ETA: 0s - loss: 0.7613 - accuracy: 0.6977
# Epoch 47: val_accuracy did not improve from 0.69047
# 439/439 [==============================] - 158s 359ms/step - loss: 0.7613 - accuracy: 0.6977 - val_loss: 0.8332 - val_accuracy: 0.6655
# Epoch 48/500
# 439/439 [==============================] - ETA: 0s - loss: 0.7595 - accuracy: 0.6986
# Epoch 48: val_accuracy did not improve from 0.69047
# 439/439 [==============================] - 157s 359ms/step - loss: 0.7595 - accuracy: 0.6986 - val_loss: 0.8186 - val_accuracy: 0.6736
# Epoch 49/500
# 439/439 [==============================] - ETA: 0s - loss: 1.0856 - accuracy: 0.5826
# Epoch 49: val_accuracy did not improve from 0.69047
# 439/439 [==============================] - 157s 359ms/step - loss: 1.0856 - accuracy: 0.5826 - val_loss: 0.9830 - val_accuracy: 0.6070
# Epoch 50/500
# 439/439 [==============================] - ETA: 0s - loss: 0.8797 - accuracy: 0.6510
# Epoch 50: val_accuracy did not improve from 0.69047
# 439/439 [==============================] - 158s 359ms/step - loss: 0.8797 - accuracy: 0.6510 - val_loss: 0.8633 - val_accuracy: 0.6602
# Epoch 51/500
# 439/439 [==============================] - ETA: 0s - loss: 0.7881 - accuracy: 0.6853
# Epoch 51: val_accuracy did not improve from 0.69047
# 439/439 [==============================] - 157s 359ms/step - loss: 0.7881 - accuracy: 0.6853 - val_loss: 0.7965 - val_accuracy: 0.6838
# Epoch 52/500
# 439/439 [==============================] - ETA: 0s - loss: 0.7572 - accuracy: 0.6965
# Epoch 52: val_accuracy improved from 0.69047 to 0.69806, saving model to best_model.h5
# 439/439 [==============================] - 157s 359ms/step - loss: 0.7572 - accuracy: 0.6965 - val_loss: 0.7494 - val_accuracy: 0.6981
# Epoch 53/500
# 439/439 [==============================] - ETA: 0s - loss: 0.7712 - accuracy: 0.6926
# Epoch 53: val_accuracy improved from 0.69806 to 0.69939, saving model to best_model.h5
# 439/439 [==============================] - 157s 359ms/step - loss: 0.7712 - accuracy: 0.6926 - val_loss: 0.7502 - val_accuracy: 0.6994
# Epoch 54/500
# 439/439 [==============================] - ETA: 0s - loss: 0.7157 - accuracy: 0.7133
# Epoch 54: val_accuracy improved from 0.69939 to 0.71683, saving model to best_model.h5
# 439/439 [==============================] - 157s 359ms/step - loss: 0.7157 - accuracy: 0.7133 - val_loss: 0.7094 - val_accuracy: 0.7168
# Epoch 55/500
# 439/439 [==============================] - ETA: 0s - loss: 0.6940 - accuracy: 0.7244
# Epoch 55: val_accuracy did not improve from 0.71683
# 439/439 [==============================] - 158s 359ms/step - loss: 0.6940 - accuracy: 0.7244 - val_loss: 0.7189 - val_accuracy: 0.7130
# Epoch 56/500
# 439/439 [==============================] - ETA: 0s - loss: 0.6939 - accuracy: 0.7283
# Epoch 56: val_accuracy improved from 0.71683 to 0.71751, saving model to best_model.h5
# 439/439 [==============================] - 157s 358ms/step - loss: 0.6939 - accuracy: 0.7283 - val_loss: 0.7237 - val_accuracy: 0.7175
# Epoch 57/500
# 439/439 [==============================] - ETA: 0s - loss: 0.6547 - accuracy: 0.7458
# Epoch 57: val_accuracy improved from 0.71751 to 0.73980, saving model to best_model.h5
# 439/439 [==============================] - 157s 359ms/step - loss: 0.6547 - accuracy: 0.7458 - val_loss: 0.6561 - val_accuracy: 0.7398
# Epoch 58/500
# 439/439 [==============================] - ETA: 0s - loss: 0.6469 - accuracy: 0.7511
# Epoch 58: val_accuracy did not improve from 0.73980
# 439/439 [==============================] - 157s 358ms/step - loss: 0.6469 - accuracy: 0.7511 - val_loss: 0.7346 - val_accuracy: 0.7078
# Epoch 59/500
# 439/439 [==============================] - ETA: 0s - loss: 0.6163 - accuracy: 0.7627
# Epoch 59: val_accuracy improved from 0.73980 to 0.75460, saving model to best_model.h5
# 439/439 [==============================] - 158s 359ms/step - loss: 0.6163 - accuracy: 0.7627 - val_loss: 0.6284 - val_accuracy: 0.7546
# Epoch 60/500
# 439/439 [==============================] - ETA: 0s - loss: 0.6150 - accuracy: 0.7637
# Epoch 60: val_accuracy did not improve from 0.75460
# 439/439 [==============================] - 158s 359ms/step - loss: 0.6150 - accuracy: 0.7637 - val_loss: 0.6477 - val_accuracy: 0.7466
# Epoch 61/500
# 439/439 [==============================] - ETA: 0s - loss: 0.5848 - accuracy: 0.7755
# Epoch 61: val_accuracy improved from 0.75460 to 0.75477, saving model to best_model.h5
# 439/439 [==============================] - 157s 358ms/step - loss: 0.5848 - accuracy: 0.7755 - val_loss: 0.6313 - val_accuracy: 0.7548
# Epoch 62/500
# 439/439 [==============================] - ETA: 0s - loss: 0.5651 - accuracy: 0.7819
# Epoch 62: val_accuracy improved from 0.75477 to 0.77131, saving model to best_model.h5
# 439/439 [==============================] - 157s 359ms/step - loss: 0.5651 - accuracy: 0.7819 - val_loss: 0.5882 - val_accuracy: 0.7713
# Epoch 63/500
# 439/439 [==============================] - ETA: 0s - loss: 0.5619 - accuracy: 0.7827
# Epoch 63: val_accuracy did not improve from 0.77131
# 439/439 [==============================] - 158s 359ms/step - loss: 0.5619 - accuracy: 0.7827 - val_loss: 0.6478 - val_accuracy: 0.7475
# Epoch 64/500
# 439/439 [==============================] - ETA: 0s - loss: 0.5427 - accuracy: 0.7899
# Epoch 64: val_accuracy improved from 0.77131 to 0.77928, saving model to best_model.h5
# 439/439 [==============================] - 157s 359ms/step - loss: 0.5427 - accuracy: 0.7899 - val_loss: 0.5673 - val_accuracy: 0.7793
# Epoch 65/500
# 439/439 [==============================] - ETA: 0s - loss: 0.5260 - accuracy: 0.7954
# Epoch 65: val_accuracy did not improve from 0.77928
# 439/439 [==============================] - 157s 357ms/step - loss: 0.5260 - accuracy: 0.7954 - val_loss: 0.5881 - val_accuracy: 0.7725
# Epoch 66/500
# 439/439 [==============================] - ETA: 0s - loss: 0.5144 - accuracy: 0.7999
# Epoch 66: val_accuracy did not improve from 0.77928
# 439/439 [==============================] - 157s 358ms/step - loss: 0.5144 - accuracy: 0.7999 - val_loss: 0.6350 - val_accuracy: 0.7606
# Epoch 67/500
# 439/439 [==============================] - ETA: 0s - loss: 0.5253 - accuracy: 0.7966
# Epoch 67: val_accuracy improved from 0.77928 to 0.78757, saving model to best_model.h5
# 439/439 [==============================] - 157s 359ms/step - loss: 0.5253 - accuracy: 0.7966 - val_loss: 0.5389 - val_accuracy: 0.7876
# Epoch 68/500
# 439/439 [==============================] - ETA: 0s - loss: 0.4878 - accuracy: 0.8083
# Epoch 68: val_accuracy did not improve from 0.78757
# 439/439 [==============================] - 158s 359ms/step - loss: 0.4878 - accuracy: 0.8083 - val_loss: 0.5675 - val_accuracy: 0.7776
# Epoch 69/500
# 439/439 [==============================] - ETA: 0s - loss: 0.4717 - accuracy: 0.8143
# Epoch 69: val_accuracy improved from 0.78757 to 0.78842, saving model to best_model.h5
# 439/439 [==============================] - 158s 359ms/step - loss: 0.4717 - accuracy: 0.8143 - val_loss: 0.5402 - val_accuracy: 0.7884
# Epoch 70/500
# 439/439 [==============================] - ETA: 0s - loss: 0.4949 - accuracy: 0.8064
# Epoch 70: val_accuracy did not improve from 0.78842
# 439/439 [==============================] - 157s 359ms/step - loss: 0.4949 - accuracy: 0.8064 - val_loss: 0.5819 - val_accuracy: 0.7669
# Epoch 71/500
# 439/439 [==============================] - ETA: 0s - loss: 0.5366 - accuracy: 0.7907
# Epoch 71: val_accuracy did not improve from 0.78842
# 439/439 [==============================] - 157s 359ms/step - loss: 0.5366 - accuracy: 0.7907 - val_loss: 0.6250 - val_accuracy: 0.7614
# Epoch 72/500
# 439/439 [==============================] - ETA: 0s - loss: 0.4791 - accuracy: 0.8117
# Epoch 72: val_accuracy improved from 0.78842 to 0.80568, saving model to best_model.h5
# 439/439 [==============================] - 159s 361ms/step - loss: 0.4791 - accuracy: 0.8117 - val_loss: 0.4921 - val_accuracy: 0.8057
# Epoch 73/500
# 439/439 [==============================] - ETA: 0s - loss: 0.4402 - accuracy: 0.8254
# Epoch 73: val_accuracy did not improve from 0.80568
# 439/439 [==============================] - 158s 361ms/step - loss: 0.4402 - accuracy: 0.8254 - val_loss: 0.5034 - val_accuracy: 0.8005
# Epoch 74/500
# 439/439 [==============================] - ETA: 0s - loss: 0.4251 - accuracy: 0.8319
# Epoch 74: val_accuracy improved from 0.80568 to 0.81067, saving model to best_model.h5
# 439/439 [==============================] - 159s 361ms/step - loss: 0.4251 - accuracy: 0.8319 - val_loss: 0.4832 - val_accuracy: 0.8107
# Epoch 75/500
# 439/439 [==============================] - ETA: 0s - loss: 0.4275 - accuracy: 0.8312
# Epoch 75: val_accuracy did not improve from 0.81067
# 439/439 [==============================] - 159s 362ms/step - loss: 0.4275 - accuracy: 0.8312 - val_loss: 0.4775 - val_accuracy: 0.8105
# Epoch 76/500
# 439/439 [==============================] - ETA: 0s - loss: 0.4070 - accuracy: 0.8384
# Epoch 76: val_accuracy did not improve from 0.81067
# 439/439 [==============================] - 158s 361ms/step - loss: 0.4070 - accuracy: 0.8384 - val_loss: 0.4834 - val_accuracy: 0.8064
# Epoch 77/500
# 439/439 [==============================] - ETA: 0s - loss: 0.5575 - accuracy: 0.7822
# Epoch 77: val_accuracy did not improve from 0.81067
# 439/439 [==============================] - 158s 361ms/step - loss: 0.5575 - accuracy: 0.7822 - val_loss: 0.5188 - val_accuracy: 0.7971
# Epoch 78/500
# 439/439 [==============================] - ETA: 0s - loss: 0.4700 - accuracy: 0.8156
# Epoch 78: val_accuracy did not improve from 0.81067
# 439/439 [==============================] - 157s 358ms/step - loss: 0.4700 - accuracy: 0.8156 - val_loss: 0.5562 - val_accuracy: 0.7848
# Epoch 79/500
# 439/439 [==============================] - ETA: 0s - loss: 0.4252 - accuracy: 0.8312
# Epoch 79: val_accuracy improved from 0.81067 to 0.81269, saving model to best_model.h5
# 439/439 [==============================] - 157s 357ms/step - loss: 0.4252 - accuracy: 0.8312 - val_loss: 0.4729 - val_accuracy: 0.8127
# Epoch 80/500
# 439/439 [==============================] - ETA: 0s - loss: 0.4015 - accuracy: 0.8408
# Epoch 80: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 358ms/step - loss: 0.4015 - accuracy: 0.8408 - val_loss: 0.4910 - val_accuracy: 0.8082
# Epoch 81/500
# 439/439 [==============================] - ETA: 0s - loss: 0.3963 - accuracy: 0.8447
# Epoch 81: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 358ms/step - loss: 0.3963 - accuracy: 0.8447 - val_loss: 4.0139 - val_accuracy: 0.1937
# Epoch 82/500
# 439/439 [==============================] - ETA: 0s - loss: 1.6497 - accuracy: 0.3454
# Epoch 82: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 360ms/step - loss: 1.6497 - accuracy: 0.3454 - val_loss: 1.3018 - val_accuracy: 0.4533
# Epoch 83/500
# 439/439 [==============================] - ETA: 0s - loss: 1.1104 - accuracy: 0.5263
# Epoch 83: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 361ms/step - loss: 1.1104 - accuracy: 0.5263 - val_loss: 1.0309 - val_accuracy: 0.5640
# Epoch 84/500
# 439/439 [==============================] - ETA: 0s - loss: 1.8124 - accuracy: 0.3355
# Epoch 84: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 159s 362ms/step - loss: 1.8124 - accuracy: 0.3355 - val_loss: 2.3989 - val_accuracy: 0.1044
# Epoch 85/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3994 - accuracy: 0.1009
# Epoch 85: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 361ms/step - loss: 2.3994 - accuracy: 0.1009 - val_loss: 2.3982 - val_accuracy: 0.0977
# Epoch 86/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3989 - accuracy: 0.1015
# Epoch 86: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 361ms/step - loss: 2.3989 - accuracy: 0.1015 - val_loss: 2.3979 - val_accuracy: 0.0952
# Epoch 87/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3966 - accuracy: 0.1023
# Epoch 87: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 360ms/step - loss: 2.3966 - accuracy: 0.1023 - val_loss: 2.3967 - val_accuracy: 0.1004
# Epoch 88/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3937 - accuracy: 0.1020
# Epoch 88: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 359ms/step - loss: 2.3937 - accuracy: 0.1020 - val_loss: 2.3987 - val_accuracy: 0.0882
# Epoch 89/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3985 - accuracy: 0.0943
# Epoch 89: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 358ms/step - loss: 2.3985 - accuracy: 0.0943 - val_loss: 2.3981 - val_accuracy: 0.0999
# Epoch 90/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3981 - accuracy: 0.0951
# Epoch 90: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 358ms/step - loss: 2.3981 - accuracy: 0.0951 - val_loss: 2.3971 - val_accuracy: 0.0869
# Epoch 91/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3971 - accuracy: 0.0968
# Epoch 91: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 358ms/step - loss: 2.3971 - accuracy: 0.0968 - val_loss: 2.3745 - val_accuracy: 0.1013
# Epoch 92/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3038 - accuracy: 0.1436
# Epoch 92: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 358ms/step - loss: 2.3038 - accuracy: 0.1436 - val_loss: 2.2742 - val_accuracy: 0.1453
# Epoch 93/500
# 439/439 [==============================] - ETA: 0s - loss: 2.2756 - accuracy: 0.1488
# Epoch 93: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 358ms/step - loss: 2.2756 - accuracy: 0.1488 - val_loss: 2.2681 - val_accuracy: 0.1450
# Epoch 94/500
# 439/439 [==============================] - ETA: 0s - loss: 2.2653 - accuracy: 0.1562
# Epoch 94: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 358ms/step - loss: 2.2653 - accuracy: 0.1562 - val_loss: 2.2600 - val_accuracy: 0.1599
# Epoch 95/500
# 439/439 [==============================] - ETA: 0s - loss: 2.2495 - accuracy: 0.1620
# Epoch 95: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 358ms/step - loss: 2.2495 - accuracy: 0.1620 - val_loss: 2.2122 - val_accuracy: 0.1736
# Epoch 96/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3961 - accuracy: 0.0970
# Epoch 96: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 358ms/step - loss: 2.3961 - accuracy: 0.0970 - val_loss: 2.3952 - val_accuracy: 0.0962
# Epoch 97/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3971 - accuracy: 0.0971
# Epoch 97: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 358ms/step - loss: 2.3971 - accuracy: 0.0971 - val_loss: 2.3983 - val_accuracy: 0.0997
# Epoch 98/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3940 - accuracy: 0.1001
# Epoch 98: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 358ms/step - loss: 2.3940 - accuracy: 0.1001 - val_loss: 2.3848 - val_accuracy: 0.1229
# Epoch 99/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3832 - accuracy: 0.1081
# Epoch 99: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 358ms/step - loss: 2.3832 - accuracy: 0.1081 - val_loss: 2.3765 - val_accuracy: 0.1140
# Epoch 100/500
# 439/439 [==============================] - ETA: 0s - loss: 2.3579 - accuracy: 0.1335
# Epoch 100: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 357ms/step - loss: 2.3579 - accuracy: 0.1335 - val_loss: 2.2704 - val_accuracy: 0.1457
# Epoch 101/500
# 439/439 [==============================] - ETA: 0s - loss: 2.2732 - accuracy: 0.1501
# Epoch 101: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 358ms/step - loss: 2.2732 - accuracy: 0.1501 - val_loss: 2.6958 - val_accuracy: 0.1182
# Epoch 102/500
# 439/439 [==============================] - ETA: 0s - loss: 2.1803 - accuracy: 0.1682
# Epoch 102: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 358ms/step - loss: 2.1803 - accuracy: 0.1682 - val_loss: 2.0270 - val_accuracy: 0.1925
# Epoch 103/500
# 439/439 [==============================] - ETA: 0s - loss: 2.0630 - accuracy: 0.1980
# Epoch 103: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 358ms/step - loss: 2.0630 - accuracy: 0.1980 - val_loss: 2.0191 - val_accuracy: 0.1951
# Epoch 104/500
# 439/439 [==============================] - ETA: 0s - loss: 2.0540 - accuracy: 0.2140
# Epoch 104: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 358ms/step - loss: 2.0540 - accuracy: 0.2140 - val_loss: 2.0926 - val_accuracy: 0.2111
# Epoch 105/500
# 439/439 [==============================] - ETA: 0s - loss: 1.9022 - accuracy: 0.2561
# Epoch 105: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 358ms/step - loss: 1.9022 - accuracy: 0.2561 - val_loss: 1.6426 - val_accuracy: 0.2955
# Epoch 106/500
# 439/439 [==============================] - ETA: 0s - loss: 1.9832 - accuracy: 0.2314
# Epoch 106: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 358ms/step - loss: 1.9832 - accuracy: 0.2314 - val_loss: 1.6408 - val_accuracy: 0.2941
# Epoch 107/500
# 439/439 [==============================] - ETA: 0s - loss: 1.6818 - accuracy: 0.2866
# Epoch 107: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 358ms/step - loss: 1.6818 - accuracy: 0.2866 - val_loss: 1.5692 - val_accuracy: 0.3031
# Epoch 108/500
# 439/439 [==============================] - ETA: 0s - loss: 1.5525 - accuracy: 0.3193
# Epoch 108: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 358ms/step - loss: 1.5525 - accuracy: 0.3193 - val_loss: 1.4832 - val_accuracy: 0.3432
# Epoch 109/500
# 439/439 [==============================] - ETA: 0s - loss: 1.4946 - accuracy: 0.3415
# Epoch 109: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 358ms/step - loss: 1.4946 - accuracy: 0.3415 - val_loss: 1.4712 - val_accuracy: 0.3418
# Epoch 110/500
# 439/439 [==============================] - ETA: 0s - loss: 1.4629 - accuracy: 0.3580
# Epoch 110: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 358ms/step - loss: 1
val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 357ms/step - loss: 1.0911 - accuracy: 0.5265 - val_loss: 1.0551 - val_accuracy: 0.5492
# Epoch 126/500
# 439/439 [==============================] - ETA: 0s - loss: 0.9971 - accuracy: 0.5724
# Epoch 126: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 357ms/step - loss: 0.9971 - accuracy: 0.5724 - val_loss: 0.9679 - val_accuracy: 0.5897
# Epoch 127/500
# 439/439 [==============================] - ETA: 0s - loss: 0.8942 - accuracy: 0.6180
# Epoch 127: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 359ms/step - loss: 0.8942 - accuracy: 0.6180 - val_loss: 1.2492 - val_accuracy: 0.5001
# Epoch 128/500
# 439/439 [==============================] - ETA: 0s - loss: 0.8908 - accuracy: 0.6206
# Epoch 128: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 160s 364ms/step - loss: 0.8908 - accuracy: 0.6206 - val_loss: 0.8233 - val_accuracy: 0.6529
# Epoch 129/500
# 439/439 [==============================] - ETA: 0s - loss: 0.7859 - accuracy: 0.6620
# Epoch 129: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 159s 362ms/step - loss: 0.7859 - accuracy: 0.6620 - val_loss: 0.7934 - val_accuracy: 0.6664
# Epoch 130/500
# 439/439 [==============================] - ETA: 0s - loss: 0.7525 - accuracy: 0.6770
# Epoch 130: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 159s 363ms/step - loss: 0.7525 - accuracy: 0.6770 - val_loss: 0.7791 - val_accuracy: 0.6700
# Epoch 131/500
# 439/439 [==============================] - ETA: 0s - loss: 0.7647 - accuracy: 0.6734
# Epoch 131: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 159s 362ms/step - loss: 0.7647 - accuracy: 0.6734 - val_loss: 0.7559 - val_accuracy: 0.6808
# Epoch 132/500
# 439/439 [==============================] - ETA: 0s - loss: 0.8603 - accuracy: 0.6353
# Epoch 132: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 159s 363ms/step - loss: 0.8603 - accuracy: 0.6353 - val_loss: 0.8654 - val_accuracy: 0.6350
# Epoch 133/500
# 439/439 [==============================] - ETA: 0s - loss: 0.7994 - accuracy: 0.6575
# Epoch 133: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 159s 362ms/step - loss: 0.7994 - accuracy: 0.6575 - val_loss: 0.7818 - val_accuracy: 0.6685
# Epoch 134/500
# 439/439 [==============================] - ETA: 0s - loss: 0.7483 - accuracy: 0.6789
# Epoch 134: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 359ms/step - loss: 0.7483 - accuracy: 0.6789 - val_loss: 0.7570 - val_accuracy: 0.6783
# Epoch 135/500
# 439/439 [==============================] - ETA: 0s - loss: 0.7152 - accuracy: 0.6920
# Epoch 135: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 359ms/step - loss: 0.7152 - accuracy: 0.6920 - val_loss: 0.7667 - val_accuracy: 0.6745
# Epoch 136/500
# 439/439 [==============================] - ETA: 0s - loss: 0.7067 - accuracy: 0.6957
# Epoch 136: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 359ms/step - loss: 0.7067 - accuracy: 0.6957 - val_loss: 0.7095 - val_accuracy: 0.6997
# Epoch 137/500
# 439/439 [==============================] - ETA: 0s - loss: 0.6782 - accuracy: 0.7073
# Epoch 137: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 359ms/step - loss: 0.6782 - accuracy: 0.7073 - val_loss: 0.7457 - val_accuracy: 0.6832
# Epoch 138/500
# 439/439 [==============================] - ETA: 0s - loss: 0.6603 - accuracy: 0.7157
# Epoch 138: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 359ms/step - loss: 0.6603 - accuracy: 0.7157 - val_loss: 0.6883 - val_accuracy: 0.7099
# Epoch 139/500
# 439/439 [==============================] - ETA: 0s - loss: 0.6400 - accuracy: 0.7233
# Epoch 139: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 359ms/step - loss: 0.6400 - accuracy: 0.7233 - val_loss: 0.6704 - val_accuracy: 0.7179
# Epoch 140/500
# 439/439 [==============================] - ETA: 0s - loss: 0.6263 - accuracy: 0.7317
# Epoch 140: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 358ms/step - loss: 0.6263 - accuracy: 0.7317 - val_loss: 0.6860 - val_accuracy: 0.7070
# Epoch 141/500
# 439/439 [==============================] - ETA: 0s - loss: 0.6144 - accuracy: 0.7369
# Epoch 141: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 359ms/step - loss: 0.6144 - accuracy: 0.7369 - val_loss: 0.6460 - val_accuracy: 0.7290
# Epoch 142/500
# 439/439 [==============================] - ETA: 0s - loss: 0.6031 - accuracy: 0.7423
# Epoch 142: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 359ms/step - loss: 0.6031 - accuracy: 0.7423 - val_loss: 0.6420 - val_accuracy: 0.7369
# Epoch 143/500
# 439/439 [==============================] - ETA: 0s - loss: 0.5996 - accuracy: 0.7457
# Epoch 143: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 359ms/step - loss: 0.5996 - accuracy: 0.7457 - val_loss: 0.6672 - val_accuracy: 0.7248
# Epoch 144/500
# 439/439 [==============================] - ETA: 0s - loss: 0.5756 - accuracy: 0.7586
# Epoch 144: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 359ms/step - loss: 0.5756 - accuracy: 0.7586 - val_loss: 0.6115 - val_accuracy: 0.7477
# Epoch 145/500
# 439/439 [==============================] - ETA: 0s - loss: 0.5594 - accuracy: 0.7682
# Epoch 145: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 359ms/step - loss: 0.5594 - accuracy: 0.7682 - val_loss: 0.6620 - val_accuracy: 0.7323
# Epoch 146/500
# 439/439 [==============================] - ETA: 0s - loss: 0.5549 - accuracy: 0.7715
# Epoch 146: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 359ms/step - loss: 0.5549 - accuracy: 0.7715 - val_loss: 0.5818 - val_accuracy: 0.7617
# Epoch 147/500
# 439/439 [==============================] - ETA: 0s - loss: 0.5581 - accuracy: 0.7716
# Epoch 147: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 359ms/step - loss: 0.5581 - accuracy: 0.7716 - val_loss: 0.5870 - val_accuracy: 0.7636
# Epoch 148/500
# 439/439 [==============================] - ETA: 0s - loss: 0.7139 - accuracy: 0.7089
# Epoch 148: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 359ms/step - loss: 0.7139 - accuracy: 0.7089 - val_loss: 0.9129 - val_accuracy: 0.6230
# Epoch 149/500
# 439/439 [==============================] - ETA: 0s - loss: 0.7268 - accuracy: 0.6968
# Epoch 149: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 359ms/step - loss: 0.7268 - accuracy: 0.6968 - val_loss: 0.6730 - val_accuracy: 0.7275
# Epoch 150/500
# 439/439 [==============================] - ETA: 0s - loss: 0.5872 - accuracy: 0.7592
# Epoch 150: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 359ms/step - loss: 0.5872 - accuracy: 0.7592 - val_loss: 0.6433 - val_accuracy: 0.7388
# Epoch 151/500
# 439/439 [==============================] - ETA: 0s - loss: 0.5432 - accuracy: 0.7790
# Epoch 151: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 359ms/step - loss: 0.5432 - accuracy: 0.7790 - val_loss: 0.5721 - val_accuracy: 0.7721
# Epoch 152/500
# 439/439 [==============================] - ETA: 0s - loss: 0.6353 - accuracy: 0.7398
# Epoch 152: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 359ms/step - loss: 0.6353 - accuracy: 0.7398 - val_loss: 0.5723 - val_accuracy: 0.7712
# Epoch 153/500
# 439/439 [==============================] - ETA: 0s - loss: 0.5096 - accuracy: 0.7927
# Epoch 153: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 359ms/step - loss: 0.5096 - accuracy: 0.7927 - val_loss: 0.5716 - val_accuracy: 0.7754
# Epoch 154/500
# 439/439 [==============================] - ETA: 0s - loss: 0.4839 - accuracy: 0.8038
# Epoch 154: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 157s 359ms/step - loss: 0.4839 - accuracy: 0.8038 - val_loss: 0.5049 - val_accuracy: 0.7970
# Epoch 155/500
# 439/439 [==============================] - ETA: 0s - loss: 0.4582 - accuracy: 0.8145
# Epoch 155: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 359ms/step - loss: 0.4582 - accuracy: 0.8145 - val_loss: 0.5439 - val_accuracy: 0.7866
# Epoch 156/500
# 439/439 [==============================] - ETA: 0s - loss: 0.4515 - accuracy: 0.8180
# Epoch 156: val_accuracy did not improve from 0.81269
# 439/439 [==============================] - 158s 359ms/step - loss: 0.4515 - accuracy: 0.8180 - val_loss: 0.4989 - val_accuracy: 0.8049
# Epoch 157/500
# 439/439 [==============================] - ETA: 0s - loss: 0.4274 - accuracy: 0.8282
# Epoch 157: val_accuracy improved from 0.81269 to 0.81529, saving model to best_model.h5
# 439/439 [==============================] - 158s 359ms/step - loss: 0.4274 - accuracy: 0.8282 - val_loss: 0.4630 - val_accuracy: 0.8153
# Epoch 158/500
# 439/439 [==============================] - ETA: 0s - loss: 0.4209 - accuracy: 0.8307
# Epoch 158: val_accuracy did not improve from 0.81529
# 439/439 [==============================] - 158s 359ms/step - loss: 0.4209 - accuracy: 0.8307 - val_loss: 0.4964 - val_accuracy: 0.8008
# Epoch 159/500
# 439/439 [==============================] - ETA: 0s - loss: 0.
[==============================] - ETA: 0s - loss: 0.1302 - accuracy: 0.9505
# Epoch 500: val_accuracy did not improve from 0.87150
# 439/439 [==============================] - 158s 359ms/step - loss: 0.1302 - accuracy: 0.9505 - val_loss: 0.4620 - val_accuracy: 0.8686

# %%
# Carrega melhor modelo obtido
model = tf.keras.models.load_model('best_model.h5')

# %%
# Extração do SNR e a classe dos sinais
snr_values = np.arange(-12, 20, 2)
num_snr = len(snr_values)
num_modulations = len(desired_vals)

# Lista de nomes das modulações
modulation_names = [
"LFM", "FM_Costas", "2PSK", "PM_Barker", "PM_Frank", "PM_P1", "PM_P2", "PM_P3", "PM_P4", "Sem Modulação", "Ruído"
]

line_styles = ['-', '--', '-.', ':'] * 6
colors = plt.cm.get_cmap('tab20', num_modulations)

# Inicializar matriz para acurácia por modulação e lista para acurácia geral
accuracy_per_modulation = np.zeros((num_modulations, num_snr))
overall_accuracy = []

# Processar cada modulação para calcular a acurácia por faixa de SNR
for mod_idx in range(num_modulations):
    modulation_indices = np.where(new_Y_test[:, mod_idx] == 1)[0]
    x_modulation = new_X_test[modulation_indices]
    y_modulation = new_Y_test[modulation_indices]
    z_modulation = new_lbl_test[modulation_indices, 1]  # SNR está na segunda coluna de lbl_data

    for snr_idx, snr in enumerate(snr_values):
        snr_indices = np.where(z_modulation == snr)[0]
        x_snr = x_modulation[snr_indices]
        y_snr = y_modulation[snr_indices]
        
        if len(x_snr) == 0:
            accuracy_per_modulation[mod_idx, snr_idx] = np.nan
            continue
        
        # Fazer predições com o modelo
        predictions_snr = model.predict(x_snr)
        
        # Calcular a acurácia
        accuracy = np.mean(np.argmax(predictions_snr, axis=1) == np.argmax(y_snr, axis=1))
        accuracy_per_modulation[mod_idx, snr_idx] = accuracy

# Calcular a acurácia geral para cada faixa de SNR
for snr in snr_values:
    snr_indices = np.where(new_lbl_test[:, 1] == snr)[0]  # SNR está na segunda coluna de lbl_data
    x_snr = new_X_test[snr_indices]
    y_snr = new_Y_test[snr_indices]

    if len(x_snr) == 0:
        overall_accuracy.append(np.nan)
        continue

    # Fazer predições com o modelo
    predictions_snr = model.predict(x_snr)

    # Calcular a acurácia geral
    accuracy = np.mean(np.argmax(predictions_snr, axis=1) == np.argmax(y_snr, axis=1))
    overall_accuracy.append(accuracy)

# Converter para array numpy para facilitar o plot
overall_accuracy = np.array(overall_accuracy)

# Plotar a acurácia por modulação
plt.figure(figsize=(14, 8))
for mod_idx in range(num_modulations):
    plt.plot(
        snr_values,
        accuracy_per_modulation[mod_idx],
        label=modulation_names[mod_idx],
        linestyle=line_styles[mod_idx % len(line_styles)],
        color=colors(mod_idx)
    )

plt.xlabel("SNR (dB)")
plt.ylabel("Acurácia")
plt.title("Acurácia de Cada Modulação em Função do SNR")
plt.legend(loc="best")
plt.grid(True)
plt.show()

# Plotar a acurácia geral
plt.figure(figsize=(10, 6))
plt.plot(snr_values, overall_accuracy, marker='o', linestyle='-', color='b', label='Acurácia Geral')

plt.xlabel("SNR (dB)")
plt.ylabel("Acurácia Geral")
plt.title("Acurácia Geral da Rede em Função do SNR")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# C:\Users\abiss\AppData\Local\Temp\ipykernel_17048\4028159649.py:12: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('tab20', num_modulations)
# 13/13 [==============================] - 2s 85ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 87ms/step
# 13/13 [==============================] - 1s 85ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 85ms/step
# 13/13 [==============================] - 1s 86ms/step
# 13/13 [==============================] - 1s 87ms/step
# 13/13 [==============================] - 1s 86ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 85ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 85ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 85ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 86ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 87ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 85ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 85ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 85ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 85ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 85ms/step
# 13/13 [==============================] - 1s 85ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 86ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 85ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 85ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 87ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 85ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 80ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 80ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 80ms/step
# 13/13 [==============================] - 1s 80ms/step
# 13/13 [==============================] - 1s 80ms/step
# 13/13 [==============================] - 1s 80ms/step
# 13/13 [==============================] - 1s 80ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 80ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 80ms/step
# 13/13 [==============================] - 1s 80ms/step
# 13/13 [==============================] - 1s 80ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 80ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 86ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 80ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 80ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 80ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 80ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 81ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 84ms/step
# 13/13 [==============================] - 1s 85ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 82ms/step
# 13/13 [==============================] - 1s 82ms/step
# 138/138 [==============================] - 12s 84ms/step
# 138/138 [==============================] - 11s 83ms/step
# 138/138 [==============================] - 12s 84ms/step
# 138/138 [==============================] - 11s 82ms/step
# 138/138 [==============================] - 12s 83ms/step
# 138/138 [==============================] - 12s 84ms/step
# 138/138 [==============================] - 12s 85ms/step
# 138/138 [==============================] - 12s 84ms/step
# 138/138 [==============================] - 12s 85ms/step
# 138/138 [==============================] - 12s 86ms/step
# 138/138 [==============================] - 12s 85ms/step
# 138/138 [==============================] - 11s 83ms/step
# 138/138 [==============================] - 12s 85ms/step
# 138/138 [==============================] - 11s 83ms/step
# 138/138 [==============================] - 12s 85ms/step
# 138/138 [==============================] - 12s 85ms/step

# %%
# Diretório de logs para o profiler
log_dir = "logs/profiler_inference"
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

# Medir o tempo de inferência
start_time = time.time()

# Realiza predições
predictions = model.predict(new_X_test)

# Medir o tempo de inferência
end_time = time.time()
inference_time = end_time - start_time

# Imprimir tempo de inferência
print(f"Tempo de inferência: {inference_time:.4f} segundos")
# Out:
# 2338/2338 [==============================] - 196s 84ms/step
# Tempo de inferência: 197.6937 segundos

# %%
# Predição utilizando melhor modelo obtido
y_pred = np.argmax(predictions, axis=1)

# Conversão do formato one hot para categórico
if len(new_Y_test.shape) > 1 and new_Y_test.shape[1] > 1:
    new_Y_test = np.argmax(new_Y_test, axis=1)

# Relatório de classificação
print("\nRelatório de Classificação:")
print(classification_report(new_Y_test, y_pred, target_names=modulation_names))

# Matriz de confusão
conf_matrix = confusion_matrix(new_Y_test, y_pred)

# Visualização da matriz de confusão
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', 
            xticklabels=modulation_names, 
            yticklabels=modulation_names)
plt.xlabel("Previsto")
plt.ylabel("Verdadeiro")
plt.title("Matriz de Confusão")
plt.show()
# Out:
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#           LFM       0.99      0.99      0.99      6800
#     FM_Costas       0.89      0.88      0.89      6800
#          2PSK       0.99      0.95      0.97      6800
#     PM_Barker       0.87      0.89      0.88      6800
#      PM_Frank       0.84      0.84      0.84      6800
#         PM_P1       0.82      0.78      0.80      6800
#         PM_P2       0.80      0.84      0.82      6800
#         PM_P3       0.86      0.84      0.85      6800
#         PM_P4       0.81      0.83      0.82      6800
# Sem Modulação       0.99      0.99      0.99      6800
#         Ruído       0.95      0.99      0.97      6800
#
#      accuracy                           0.89     74800
#     macro avg       0.89      0.89      0.89     74800
#  weighted avg       0.89      0.89      0.89     74800
